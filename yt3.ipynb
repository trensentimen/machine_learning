# %%
import pandas as pd
from googleapiclient.discovery import build

# %%
def video_comments(video_id):
	# empty list for storing reply
	replies = []

	# creating youtube resource object
	youtube = build('youtube', 'v3', developerKey=api_key)

	# retrieve youtube video results
	video_response = youtube.commentThreads().list(part='snippet,replies', videoId=video_id).execute()

	# iterate video response
	while video_response:

		# extracting required info
		# from each result object
		for item in video_response['items']:

			# Extracting comments ()
			published = item['snippet']['topLevelComment']['snippet']['publishedAt']
			user = item['snippet']['topLevelComment']['snippet']['authorDisplayName']

			# Extracting comments
			comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
			likeCount = item['snippet']['topLevelComment']['snippet']['likeCount']

			replies.append([published, user, comment, likeCount])

			# counting number of reply of comment
			replycount = item['snippet']['totalReplyCount']

			# if reply is there
			if replycount>0:
				# iterate through all reply
				for reply in item['replies']['comments']:

					# Extract reply
					published = reply['snippet']['publishedAt']
					user = reply['snippet']['authorDisplayName']
					repl = reply['snippet']['textDisplay']
					likeCount = reply['snippet']['likeCount']

					# Store reply is list
					#replies.append(reply)
					replies.append([published, user, repl, likeCount])

			# print comment with list of reply
			#print(comment, replies, end = '\n\n')

			# empty reply list
			#replies = []

		# Again repeat
		if 'nextPageToken' in video_response:
			video_response = youtube.commentThreads().list(
					part = 'snippet,replies',
					pageToken = video_response['nextPageToken'],
					videoId = video_id
				).execute()
		else:
			break
	#endwhile
	return replies

# %%
# isikan dengan api key Anda
api_key = 'AIzaSyCpK-KkGkytwXrETUavQrcczh2R3hLTGaE'
# Enter video id
# contoh url video = https://www.youtube.com/watch?v=sTsY2U9fcik
video_id = "sTsY2U9fcik" #isikan dengan kode / ID video

# Call function
comments = video_comments(video_id)

comments
# Out:
# [['2023-10-31T00:01:43Z',
#   '4LDHY3 BL4CK',
#   '2 periode kmrn q pilih Prabowo..karena wakilx skrg gibran saya g pilih Prabowo lagi',
#   0],
#  ['2023-10-30T20:52:34Z', 'apps dasok', 'Paten pak wo', 0],
#  ['2023-10-30T15:19:25Z',
#   'maisa Mudrikah',
#   'Paten tp pemenangnya ganjar mahfud woooo',
#   0],
#  ['2023-10-30T15:06:05Z',
#   'Info News Rusia',
#   'yg kurang di tegakkan, makanya korupsi merajalela. Siapa yg memberi harapan besar meluruskan hukum? <br>Siapa lagi kalau bukan pak Mahfud...berantas koruptor yg jadi penyakit negara kita. Jangan asal pilih karena fanatik. Karena fanatik itu membodohkanmu.',
#   0],
#  ['2023-10-30T12:11:06Z', 'Bagus Soek', 'Kalian tau apa soal politik😂', 0],
#  ['2023-10-30T05:50:03Z',
#   'jawiro wiro',
#   'pa bowo ga perlu cawapres berpengalaman yg penting punya suara dan menang...anak kemaren sore mau mimp. para jendral😂😂..',
#   0],
#  ['2023-10-30T02:49:44Z',
#   'Ety Murly',
#   'Alhamdulillah Dukung Penuh Prabowo Gibran',
#   0],
#  ['2023-10-29T18:28:56Z',
#   'Rafi Dh',
#   'KOMENTAR W CUMA INI<br>( KASIAN PAK PRABOWO. )',
#   0],
#  ['2023-10-29T15:23:34Z', 'Anjas Pratama', 'Gak paten Smoga kalah', 0],
#  ['2023-10-29T11:52:29Z',
#   'Mikasa 123',
#   'Saya milih Prabowo- Gibran. Karena ada ketauan pihak kubu Ganjar bagi2 uang/sbako buat milih dia dengan kasih ft KTP kita. Plis deh liaht fakta',
#   0],
#  ['2023-10-29T09:31:30Z',
#   'Raika Villi',
#   'Dulu sya pilih brabowo.untuk sekarang tidak.karna cawapresnya gk mutu',
#   0],
#  ['2023-10-29T09:30:48Z',
#   'Raika Villi',
#   'Ogah gua milih prabowo.caparesnya anak si plongo',
#   0],
#  ['2023-10-29T06:04:18Z',
#   'Ir. Ari Rahardjo',
#   'Partai kalau mendatangkan rakyat kampanye  pasti di kasih uang Rp. 100 - 200.000, padahal Menteri bersama dengan Partai korupsi sampai Triliunan uang dari pajak rakyat.???????',
#   2],
#  ['2023-10-29T03:33:20Z',
#   'lydya juanita',
#   'Prabowo Gibran next President &amp; wapres ❤.',
#   0],
#  ['2023-10-29T01:35:16Z', 'Yadi Mulyadi', 'Saya suka pasangan pragi', 0],
#  ['2023-10-29T01:02:09Z', 'Thedee', 'Anak ingusan dinasti 😅', 0],
#  ['2023-10-29T01:01:09Z',
#   'Ipuk Bancak',
#   'Saya blunder tdiny ke pak prabowo,selama 2 periode,skrng saya milih anis ,klo gak ganjar',
#   1],
#  ['2023-10-29T00:02:34Z', 'Helena Napitupulu', 'Patennn❤', 0],
#  ['2023-10-28T07:48:47Z',
#   'arjuna3780',
#   'Bocil Politik Buzuk : &quot;Makasih Paman..Nanti Menangkan kami saat sengketa hasil Pilpres di MK Ya Paman..❤ You Paman&quot;😂😂😂',
#   2],
#  ['2023-10-28T04:17:28Z',
#   'Opan 11',
#   'buah jatu ga bakal jauh dari pohon nya. haha udah ragu pilih prabowo yg tadinya semangat dukung',
#   0],
#  ['2023-10-28T00:30:45Z',
#   'Rendi Yosan',
#   'Harusnya Pak Prabowo bisa bijaksana, dengan menolak usungan Cawapres dari hasil putusan MK yang tergesa gesa.',
#   3],
#  ['2023-10-26T10:59:43Z', 'Wayan Mariana', 'Gak bahaya ta 😂😂😂.', 0],
#  ['2023-10-26T00:17:32Z',
#   'Asrul Araha',
#   'Apa pun yang anda katakan tentang beliau saya tetap Prabowo',
#   1],
#  ['2023-10-25T15:47:21Z', 'Saderach WP', 'GaMa is the best', 0],
#  ['2023-10-25T13:30:06Z',
#   'Dani Begok Amat',
#   'Serigala Tua yg sangat berambisi dan Kamu Gibran karena Bapakmu dan Pamanmu yg mempermudah begitu kamu merasa bangga kayak kamu mewakili semua generasi Milenial ? Generasi Milenial berdikari diatas kakinya sendiri !!!!!!!!!!!!!!!',
#   0],
#  ['2023-10-25T12:29:44Z', 'Andi Hasibuan', 'Kompas ganjarist', 0],
#  ['2023-10-25T12:21:19Z', 'Ustadz Ustadz', 'Salah menafsirkan bang toto.', 0],
#  ['2023-10-25T12:06:33Z',
#   'Suyani Sulaiman',
#   'Kamu itu gandeng sama siapa saja ,tetap kalah wowo ,',
#   0],
#  ['2023-10-25T12:01:32Z', 'Tekekmrembet#', 'Samgat salah bong 👺💀👺', 0],
#  ['2023-10-25T11:44:58Z', 'andri nurdin', 'Salah pilih cawapres😂😂😂', 0],
#  ['2023-10-25T11:40:31Z',
#   'Gono Kompet',
#   'Saya tetap yang sudah jelas kerjanya. Gama',
#   2],
#  ['2023-10-25T11:38:01Z',
#   'Ju Ginting',
#   'Lo Wo manusia kemaruk....Gibran sdh jadi Kebo Ijo',
#   0],
#  ['2023-10-25T11:32:19Z',
#   'Bangkit',
#   'HEBAT SI GIVE RUN .TURUNAN PEMBERONTAK BERGABUNG DG KELUARGA PENGHIANAT.AYO KYAI TALKEH BERGABUNGLAH.YANG PENTING DPT AMPLOP..',
#   1],
#  ['2023-10-25T11:31:56Z',
#   'O_PUNK75',
#   'KALO ADA APA2, GIBRAN MAJU JADI RI-1.',
#   2],
#  ['2023-10-25T12:09:40Z',
#   'Apa Macam',
#   'Ya sudah jelas.. umur 72 mah rawan sakit..',
#   0],
#  ['2023-10-25T11:30:01Z',
#   'Gus Wedi',
#   'Penentu kemenangan prabowo, gibran atau jkw  pak ?? pertanyaanya kemenangan yg bagaimana coba terka.😂😂',
#   0],
#  ['2023-10-25T11:26:50Z',
#   "Bervik's Cristover",
#   'Semoga prabowo &amp; gibran nyungsep putaran pertama akibat menghalalkan segala cara. Ganjar dan anies lolos putaran ke dua lalu Ganjar berhasil jd pemenang itu harapan rakyat indonesia.',
#   2],
#  ['2023-10-28T08:25:28Z',
#   'SANTUY PARUY',
#   'masyallah doain orang yang jelek jelek nanti kalo berbalik gimana om ?',
#   0],
#  ['2023-10-25T11:24:24Z',
#   'Feri Indawan',
#   'Wowo....udah 2x kau gagal...mau 3 x ya kalh nya....kacian deh lho wowo....emang sehebt apa gibran.....kslian berdua pasti nyungsep 2024 nanti😂😂😂😂',
#   3],
#  ['2023-10-28T08:26:09Z',
#   'SANTUY PARUY',
#   'ga kesian sih orang dia kaya mau maju juga suka suka dia lah ,yang kesian mah masyarakat yang apa apa nyalahin pemerintah doang bisa nya',
#   0],
#  ['2023-10-25T11:21:11Z', 'HOBI MANCING', 'Lucuan kayak ria jenaka..', 0],
#  ['2023-10-25T11:18:43Z',
#   'Jahusor Simamora',
#   'Apapun dibilang aku tetap pilih yang terbaik Ganjar-Mahfud.',
#   2],
#  ['2023-10-25T11:17:27Z',
#   'Yuli Herawati',
#   'Ke Prabowo yg komentar negatif semua seolah olah <br><br>Pasangan yg dua lebih baik<br><br>Lihat donk dijalan menuju ke kpu<br>Masa ga kebagi dua<br>Full penuh pendukung Prabowo<br><br>Jadi ketiga pasangan mempunyai peluang<br><br>Yg sejuk rukun damai <br>Jgn dengki terus<br>Malu sama pa Anis dan pa Ganjar<br>Yg notabenya beliau saling menghormati beda pandangan...',
#   2],
#  ['2023-10-25T13:44:42Z',
#   'Fortuna HRD Training Center',
#   'Setuju … komentar yg bijak 👍',
#   0],
#  ['2023-10-25T11:16:07Z',
#   'Rasih Gmail',
#   'Bagus PAK Bagus,kan Bapak SUDAH Merasakan Kekalahan PILPRES 3x... NAH SUPAYA GENAP KALAH ke 4x ITU SANGAT BAGUS PAK.... MANUSIA AMBISIUS Plus Manusia HAUS KEKUASAAN,Makjuss.... MEMANG Bapak Gak ADA YG KASIH INFO, JIKA Di MEDSOS,BAPAK SUDAH SEJAK Keluar PUTUSAN MK, Pemberitaan MENGENAI GIBRAN YG AKAN MENJADI BACAWAPRES PRABOWO SDH MENDAPATKAN SENTIMEN NEGATIF DARI PUBLIK,JIKA SENTIMEN NEGATIF ITU BERLANJUT TERUS SAMPAI BULAN FEBRUARI TAHUN 2023.....CONGRATULATION ,I WILL BE Say Goodbye To U....',
#   3],
#  ['2023-10-25T11:37:05Z', 'n0xz zeek', 'Betul', 0],
#  ['2023-10-28T10:36:13Z', 'TM627', 'Jadi mikir dua kali milih bpk ps', 0],
#  ['2023-10-25T11:15:22Z', 'Bait Bait', 'Salah', 0],
#  ['2023-10-25T11:12:43Z',
#   'Ashuri Tuban',
#   'Pengamat botak ini slalu menilai gibran negatif trus,, biar tambah lebar itu botak,, gas pol mas gibran.,💪💪💪',
#   7],
#  ['2023-10-25T23:07:53Z',
#   'Renaldi Lesmana',
#   'Emang bos kalo diperhatiin dari dulu dia kaya pro banteng terus',
#   0],
#  ['2023-10-28T15:13:05Z',
#   'Erlangga movie',
#   'makanya 2024 hayu kita gasskan tenggelamkan partai banteng 😂😂',
#   0],
#  ['2023-10-25T11:11:41Z', 'Moch Syahrial', 'Ulasan koplak', 0],
#  ['2023-10-25T11:11:23Z',
#   'Syafrul Abdullah',
#   'Si Botak ini gk cocok jdi pengamat politik krn dia pendukung Ganjar...Rocky donk jdi pengamat nya..',
#   0],
#  ['2023-10-25T11:10:40Z',
#   'Moel Awan',
#   'Sukses... sukses.... maju terus demi kami Rakyat Indonesia. LopeU pak Prabowo &amp; Mas Gibran❤',
#   7],
#  ['2023-10-25T11:10:26Z',
#   'BINTANG FOOTBALL',
#   'Terlihat seperti kakek dan Cucu.',
#   0],
#  ['2023-10-25T11:10:25Z',
#   'Emma Emma',
#   'HANYA GANJAR YANG TERBAIK AMANAH ADIL TEGAS BERINTEGRITAS BERWAWASAN DAN PENUH PRESTASI AKAN MENJADIKAN INDONESIA AMAN MAJU BERJAYA SEJAHTERA 🇮🇩🇮🇩💟💟👍👍 MENANG HATRIK DENGAN 1 PUTARAN 60.7%',
#   4],
#  ['2023-10-25T11:10:21Z', 'asiknya di desa', 'Kalah lagi lu', 0],
#  ['2023-10-25T11:09:31Z',
#   'Aki Soekamad',
#   'KOALISI GANJAR - KOALISI PRABOWO ADALAH SATU PERUT.<br>Masyarakat sudah cerdas, sandiwaranya mudah dibaca😂',
#   4],
#  ['2023-10-28T08:24:47Z', 'SANTUY PARUY', '???', 0],
#  ['2023-10-25T11:09:27Z',
#   'Emma Emma',
#   'TAK ADA TEMPAT DIHATI RAKYAT UNTUK PENCULIK DAN PEMBUNUH PADA RAKYATNYA SENDIRI TANPA PROSES HUKUM 🇮🇩🇮🇩💟💟👍👍',
#   3],
#  ['2023-10-25T11:30:13Z', 'Anak Terpelajar', 'Setuju<br>Nkri harga mati', 1],
#  ['2023-10-25T11:05:50Z',
#   'Nathan Izqian',
#   'Maaf pak kali ini kamu salah lagi.<br>Soalnya ini anak kelihatan aj polos aslinya buluuuussss.......<br><br>2024 bapak harus siap kalah ke 4x',
#   1],
#  ['2023-10-25T11:04:45Z',
#   'Wilson Napitupulu',
#   'Aduh kasihan Prabowo berharap Gibran bisa meraih suara di Solo dan Jateng. Pemilih sudah cerdas tidak akan mendukung bocah penghianat',
#   6],
#  ['2023-10-25T11:14:28Z',
#   'Ashuri Tuban',
#   'Napitupulu,,, satu geng dengan Andrianapi, ini orang.🤸\u200d♂️🤸\u200d♂️🤸\u200d♂️🤸\u200d♂️',
#   1],
#  ['2023-10-29T10:13:32Z', 'FM AUDIO&PHONE', 'ojo ngambek boss🤣🤣', 1],
#  ['2023-10-30T12:12:01Z', 'Bagus Soek', 'Lu tau apa soap politik bocah', 0],
#  ['2023-10-25T11:01:26Z',
#   'Gus Wedi',
#   'Woo...woo , ditipu berkali kali kok masih percaya sih..!!! Mikir.😂😂',
#   1],
#  ['2023-10-25T10:56:53Z',
#   'Singa Anom',
#   'Hoax lagi.....................<a href="about:invalid#zCSafez"></a><a href="about:invalid#zCSafez"></a><a href="about:invalid#zCSafez"></a><a href="about:invalid#zCSafez"></a><a href="about:invalid#zCSafez"></a><a href="about:invalid#zCSafez"></a><a href="about:invalid#zCSafez"></a><a href="about:invalid#zCSafez"></a>',
#   0],
#  ['2023-10-25T10:56:12Z',
#   'Rakyat Jelata',
#   'Nggak salah kok pak, biar sama-sama nyungsep nantinya.',
#   3],
#  ['2023-10-25T11:29:48Z', 'Anak Terpelajar', 'Amin', 0],
#  ['2023-10-25T10:55:30Z',
#   'karma berjalan',
#   'Ada anak yang kepingin wapres malah yang dapat anak yang silent',
#   0]]

# %%
df = pd.DataFrame(comments, columns=['publishedAt', 'authorDisplayName', 'textDisplay', 'likeCount'])
df
# Out:
#              publishedAt authorDisplayName  \
# 0   2023-10-31T00:01:43Z      4LDHY3 BL4CK
# 1   2023-10-30T20:52:34Z        apps dasok
# 2   2023-10-30T15:19:25Z    maisa Mudrikah
# 3   2023-10-30T15:06:05Z   Info News Rusia
# 4   2023-10-30T12:11:06Z        Bagus Soek
# ..                   ...               ...
# 66  2023-10-25T11:01:26Z          Gus Wedi
# 67  2023-10-25T10:56:53Z        Singa Anom
# 68  2023-10-25T10:56:12Z     Rakyat Jelata
# 69  2023-10-25T11:29:48Z   Anak Terpelajar
# 70  2023-10-25T10:55:30Z    karma berjalan
#
#                                           textDisplay  likeCount
# 0   2 periode kmrn q pilih Prabowo..karena wakilx ...          0
# 1                                        Paten pak wo          0
# 2            Paten tp pemenangnya ganjar mahfud woooo          0
# 3   yg kurang di tegakkan, makanya korupsi merajal...          0
# 4                        Kalian tau apa soal politik😂          0
# ..                                                ...        ...
# 66  Woo...woo , ditipu berkali kali kok masih perc...          1
# 67  Hoax lagi.....................<a href="about:i...          0
# 68  Nggak salah kok pak, biar sama-sama nyungsep n...          3
# 69                                               Amin          0
# 70  Ada anak yang kepingin wapres malah yang dapat...          0
#
# [71 rows x 4 columns]

# %%
df.to_csv('youtube-comments.csv', index=False)
