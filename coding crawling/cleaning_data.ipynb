# %%
import sys
sys. version
# Out:
# '3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]'

# %%
# !pip install emoji
# !pip install Sastrawi
# !pip3 install swifter
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: emoji in c:\users\ichsam\appdata\roaming\python\python311\site-packages (2.8.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Sastrawi in c:\users\ichsam\appdata\roaming\python\python311\site-packages (1.0.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: swifter in c:\users\ichsam\appdata\roaming\python\python311\site-packages (1.4.0)
# Requirement already satisfied: pandas>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from swifter) (2.0.3)
# Requirement already satisfied: psutil>=5.6.6 in c:\programdata\anaconda3\lib\site-packages (from swifter) (5.9.0)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in c:\programdata\anaconda3\lib\site-packages (from swifter) (2023.6.0)
# Requirement already satisfied: tqdm>=4.33.0 in c:\programdata\anaconda3\lib\site-packages (from swifter) (4.65.0)
# Requirement already satisfied: click>=8.0 in c:\programdata\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (8.0.4)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\programdata\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (2023.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (23.1)
# Requirement already satisfied: partd>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\programdata\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: toolz>=0.10.0 in c:\programdata\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\programdata\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (6.0.0)
# Requirement already satisfied: numpy>=1.21 in c:\programdata\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0.0->swifter) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0.0->swifter) (2023.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.33.0->swifter) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask[dataframe]>=2.10.0->swifter) (3.11.0)
# Requirement already satisfied: locket in c:\programdata\anaconda3\lib\site-packages (from partd>=1.2.0->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->swifter) (1.16.0)

# %%
pip install wheel setuptools pip --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: wheel in c:\programdata\anaconda3\lib\site-packages (0.38.4)
# Collecting wheel
#   Obtaining dependency information for wheel from https://files.pythonhosted.org/packages/fa/7f/4c07234086edbce4a0a446209dc0cb08a19bb206a3ea53b2f56a403f983b/wheel-0.41.3-py3-none-any.whl.metadata
#   Using cached wheel-0.41.3-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (68.0.0)
# Collecting setuptools
#   Obtaining dependency information for setuptools from https://files.pythonhosted.org/packages/bb/26/7945080113158354380a12ce26873dd6c1ebd88d47f5bc24e2c5bb38c16a/setuptools-68.2.2-py3-none-any.whl.metadata
#   Using cached setuptools-68.2.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pip in c:\programdata\anaconda3\lib\site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/47/6a/453160888fab7c6a432a6e25f8afe6256d0d9f2cbd25971021da6491d899/pip-23.3.1-py3-none-any.whl.metadata
#   Using cached pip-23.3.1-py3-none-any.whl.metadata (3.5 kB)
# Using cached wheel-0.41.3-py3-none-any.whl (65 kB)
# Using cached setuptools-68.2.2-py3-none-any.whl (807 kB)
# Using cached pip-23.3.1-py3-none-any.whl (2.1 MB)
# Installing collected packages: wheel, setuptools, pip
# Successfully installed pip-23.3.1 setuptools-68.2.2 wheel-0.41.3
#   WARNING: The script wheel.exe is installed in 'C:\Users\ICHSAM\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pip.exe, pip3.11.exe and pip3.exe are installed in 'C:\Users\ICHSAM\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.75 requires requests_mock, which is not installed.
# conda-repo-cli 1.0.75 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.75 requires PyYAML==6.0.1, but you have pyyaml 6.0 which is incompatible.

# %%
pip install gensim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in c:\programdata\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\programdata\anaconda3\lib\site-packages (from gensim) (1.24.3)
# Requirement already satisfied: scipy>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from gensim) (1.11.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\programdata\anaconda3\lib\site-packages (from gensim) (5.2.1)
# Requirement already satisfied: FuzzyTM>=0.4.0 in c:\users\ichsam\appdata\roaming\python\python311\site-packages (from gensim) (2.0.5)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim) (2.0.3)
# Requirement already satisfied: pyfume in c:\users\ichsam\appdata\roaming\python\python311\site-packages (from FuzzyTM>=0.4.0->gensim) (0.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2023.3)
# Requirement already satisfied: simpful in c:\users\ichsam\appdata\roaming\python\python311\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.11.0)
# Requirement already satisfied: fst-pso in c:\users\ichsam\appdata\roaming\python\python311\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)
# Requirement already satisfied: miniful in c:\users\ichsam\appdata\roaming\python\python311\site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: textblob in c:\users\ichsam\appdata\roaming\python\python311\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\programdata\anaconda3\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.65.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -U deep-translator
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: deep-translator in c:\users\ichsam\appdata\roaming\python\python311\site-packages (1.11.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in c:\programdata\anaconda3\lib\site-packages (from deep-translator) (4.12.2)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in c:\programdata\anaconda3\lib\site-packages (from deep-translator) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2023.7.22)

# %%
pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imblearn in c:\users\ichsam\appdata\roaming\python\python311\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\programdata\anaconda3\lib\site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.11.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install emoji --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: emoji in c:\users\ichsam\appdata\roaming\python\python311\site-packages (2.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in c:\users\ichsam\appdata\roaming\python\python311\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import nltk
from nltk.tokenize import word_tokenize


# UNCOMMENT "nltk.download()" untuk  pertamakali run, untuk run selanjutnya comment kembali
# nltk.download()

# %%
import pandas as pd 
import numpy as np
import re
import string
# import emoji

# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
# from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary

import swifter
from tqdm import tqdm 

# from nltk.tokenize import word_tokenize
# import nltk
# nltk.download()

import ast 

import gensim
from gensim import corpora, models

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report, accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
from deep_translator import GoogleTranslator

# %%
dfc = pd.read_csv("youtube-comments (5).csv");

# %%
dfc['textDisplay'][0]
# Out:
# 'Mas Gibran pria mudah <br>Adalah generasi penerus<br>Yg mementingkan kepetingan<br>Golongan dripd kepentingan pribadi...mas Gibran maju terus...'

# %%
dfc.head()
# Out:
#             publishedAt authorDisplayName  \
# 0  2023-11-04T02:02:00Z       umi kaimana
# 1  2023-11-03T23:17:05Z       Laode Handi
# 2  2023-11-03T22:39:48Z      Aris Santoso
# 3  2023-11-03T15:35:49Z               AWU
# 4  2023-11-03T14:33:52Z    Gogolali Kroto
#
#                                          textDisplay  likeCount
# 0  Mas Gibran pria mudah <br>Adalah generasi pene...        0.0
# 1  Prediksi saya Prabowo Gibran menang diatas 50 ...        0.0
# 2          Gibran kucluk gayane koyo baim wong......        0.0
# 3  Semenjak kalah terus jadi menhan jadi kaga res...        0.0
# 4    Mantap kali...  Pak Prabowo dan Mas Gibran 🎉❤🇮🇩        0.0

# %%
dfc
# Out:
#                                           publishedAt  \
# 0                                2023-11-04T02:02:00Z
# 1                                2023-11-03T23:17:05Z
# 2                                2023-11-03T22:39:48Z
# 3                                2023-11-03T15:35:49Z
# 4                                2023-11-03T14:33:52Z
# 5                                2023-11-03T14:16:19Z
# 6                                2023-11-03T14:13:30Z
# 7                                2023-11-03T09:53:26Z
# 8                                2023-11-03T07:41:13Z
# 9                                2023-11-03T07:39:50Z
# 10                               2023-11-03T07:39:13Z
# 11                               2023-11-03T03:07:36Z
# 12                               2023-11-03T00:51:29Z
# 13                               2023-11-03T00:15:53Z
# 14                               2023-11-02T23:27:36Z
# 15                               2023-11-02T22:50:02Z
# 16                               2023-11-03T14:13:44Z
# 17                               2023-11-02T19:38:32Z
# 18                               2023-11-02T19:37:29Z
# 19                               2023-11-02T18:19:33Z
# 20                               2023-11-02T18:00:43Z
# 21                               2023-11-02T16:25:00Z
# 22                               2023-11-02T14:56:41Z
# 23                               2023-11-02T14:28:12Z
# 24                               2023-11-03T08:41:05Z
# 25                               2023-11-03T16:21:07Z
# 26                               2023-11-02T14:12:26Z
# 27                               2023-11-02T11:34:41Z
# 28  <br>Harus manfaatkan peluang yang sudah dibuka...
# 29                               2023-11-03T14:14:35Z
# 30                               2023-11-02T11:32:40Z
# 31                               2023-11-02T11:29:44Z
# 32                               2023-11-02T11:28:23Z
# 33                               2023-11-02T10:32:17Z
# 34                               2023-11-03T07:08:10Z
# 35                               2023-11-02T10:29:05Z
# 36                               2023-11-02T10:25:23Z
# 37                               2023-11-02T10:21:52Z
# 38                               2023-11-03T07:12:40Z
# 39                               2023-11-02T10:00:41Z
# 40                               2023-11-02T10:18:02Z
# 41                               2023-11-02T09:49:33Z
# 42                               2023-11-02T09:47:40Z
# 43                               2023-11-02T09:29:32Z
# 44                               2023-11-02T09:24:10Z
# 45                               2023-11-02T09:24:37Z
# 46                               2023-11-02T09:40:45Z
# 47                               2023-11-02T09:23:37Z
# 48                               2023-11-02T09:08:31Z
# 49                               2023-11-02T08:55:11Z
# 50                               2023-11-02T09:38:56Z
# 51                               2023-11-02T09:46:16Z
# 52                               2023-11-02T08:40:55Z
#
#           authorDisplayName  \
# 0               umi kaimana
# 1               Laode Handi
# 2              Aris Santoso
# 3                       AWU
# 4            Gogolali Kroto
# 5                G Hasibuan
# 6                G Hasibuan
# 7              Sahmal Bebie
# 8              Mian Siahaan
# 9              Mian Siahaan
# 10             Mian Siahaan
# 11           Designbyardans
# 12            Lissa Hantono
# 13              Yudhis Tira
# 14              Robi Godean
# 15             Rusdi Faisal
# 16       pencari ketenangan
# 17                  Purwadi
# 18                  Purwadi
# 19         Avanza Jual beli
# 20              azid jajili
# 21           Nurdiah Kristi
# 22                Niko Danu
# 23             @ANDRE MANIA
# 24           Kewaige kyliee
# 25                 VALE IJE
# 26                Joy Rohli
# 27              Ganda Purba
# 28                        0
# 29       pencari ketenangan
# 30              Jacky Aulia
# 31            Pujiatmoko 77
# 32              Jacky Aulia
# 33              Alin jennie
# 34              Salsa Micin
# 35              Dedi Swandi
# 36             Immunoterapi
# 37                 Rudy . S
# 38              Salsa Micin
# 39                Enor Juni
# 40         [ Kizuna Kaori ]
# 41      Budipapabumi Hening
# 42          Casper Himalaya
# 43                        A
# 44               Oleh Soleh
# 45               Oleh Soleh
# 46           Muhammad Rizal
# 47             Stb Indihome
# 48      Divide de' memories
# 49  Deddy andrian Kurniawsn
# 50           Muhammad Rizal
# 51       MBNEM ROOSTER FARM
# 52              Abboy Topan
#
#                                           textDisplay  likeCount
# 0   Mas Gibran pria mudah <br>Adalah generasi pene...        0.0
# 1   Prediksi saya Prabowo Gibran menang diatas 50 ...        0.0
# 2           Gibran kucluk gayane koyo baim wong......        0.0
# 3   Semenjak kalah terus jadi menhan jadi kaga res...        0.0
# 4     Mantap kali...  Pak Prabowo dan Mas Gibran 🎉❤🇮🇩        0.0
# 5   Kenapa pada protes ya.....bila perlu syaratnya...        0.0
# 6   Katanya negara demokrasi.....siapa aja yg masu...        0.0
# 7                            Demokrasi Indonesia mati        0.0
# 8                                      Ganjar aja deh        0.0
# 9   Katanya ngk bisa. Batas usia. Mana yg benar ia ??        1.0
# 10                                        Emng jd ???        0.0
# 11  tetep yakin Prabowo Gibran menang di putaran k...        2.0
# 12                          2024 untuk prabowo gibran        2.0
# 13           Usianya paling sepuh adalah pilihan saya        0.0
# 14          Ganjar,mahfud bos,  ora sudi pilih gibran        1.0
# 15  Rakyat bener&quot; jijik dg caranya jadi cawapres        2.0
# 16                 Makanya mending coblos Prabowo aja        0.0
# 17    Prabowo gibran akan gugur ini udah ingkar janji        0.0
# 18                        Gk akan jadi untuk slamanya        0.0
# 19                 Prabowo-Gibran tetap jadi R1, 🎉🎉🎉🎉        4.0
# 20  Harusnya prabowo anies,tapi kalau begini mendi...        1.0
# 21                                         Gak ngurus        0.0
# 22                         Lihat mukanya aja dah muak        0.0
# 23  SEMOGA GAGAL, SAYA SELALU MENDUKUNG PAK PRABOW...        3.0
# 24                                          iya bener        0.0
# 25               Emang kenapa klw wakilnya Gibran,,??        1.0
# 26    Mau tanya min ,gibran udah keluar blm dari pdip        0.0
# 27                    Maju terus Gibran - Prabowo  😹😹        NaN
# 28                                                NaN        NaN
# 29  Cawapres aja bangga... Pilih dunk Prabowo capr...        0.0
# 30  LANJUTKAN KEDUNGUAN KALIAN DGN KOMENTAR GIBAH....        0.0
# 31  Blm jadi pemilu di jamin SDH kalah...amin Ganj...        2.0
# 32  KASIAN GANJAR KALO GAK ADA PDIP🤣 KASIAN ANIES ...        0.0
# 33    Ogah bngt pilih Cawapres Karbitan  di Paksa . 😊       10.0
# 34  Daripada pilih kelompok Durhaka Amin Rais Cak ...        3.0
# 35                                           Ampassss        0.0
# 36  Semangat nyoblos Prabowo Gibran untuk Indonesi...        5.0
# 37  Tim pemenangan prabowo<br>Aldi taher ,kiki, ka...        6.0
# 38  Roki gerunk dan Amin Rais dukung Anies-Muhaimin 🤣        0.0
# 39                             Moal milih tetep anies        1.0
# 40                                               Rais        0.0
# 41                              Tim pembela nepotisme        4.0
# 42                               Santai, casual, jos❤        0.0
# 43                   Tenang tenang pak MK MK wakkk🤪🤪🤪        5.0
# 44  GIBRAN BUKAN KAKENG KALENG 25 RH ANAK JOKO W 3...        1.0
# 45                                              35 th        0.0
# 46  @Oleh Soleh emil dardak kader demokrat wakil k...        1.0
# 47                                  Terimakasih paman        4.0
# 48                       2024 ALL IN PRABOWO GIBRAN ❤       10.0
# 49       BALI MENANG TELAK PRAGIB INDONESIA EMAS 2024        6.0
# 50  100% ir soekarno masih PDIP bos 😎 liat berita ...        2.0
# 51       Menangis bro g ada kartunya prabowo menang .        0.0
# 52                          Gibran sang penghianat...        0.0

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   publishedAt        53 non-null     object
#  1   authorDisplayName  53 non-null     object
#  2   textDisplay        52 non-null     object
#  3   likeCount          51 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 1.8+ KB

# %%
# hapus data nan
df_cleaned = dfc.dropna()

# %%
for tweet in tqdm(df_cleaned['textDisplay']):
    print(tweet)
    tweet = re.sub("@[A-Za-z0-9]+","",tweet) #Remove @ sign
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 22590.51it/s]
# Mas Gibran pria mudah <br>Adalah generasi penerus<br>Yg mementingkan kepetingan<br>Golongan dripd kepentingan pribadi...mas Gibran maju terus...
# Prediksi saya Prabowo Gibran menang diatas 50 persen dgn alasan, pemilih   Prabowo,pemilih SBY, relawan Gibran, mesin koalsi indo majukeluarga Soeharto,Kel purnawirawan,Kel yg diberi bea siswa dll
# Gibran kucluk gayane koyo baim wong......
# Semenjak kalah terus jadi menhan jadi kaga resep udah <br>Mending anies lah
# Mantap kali...  Pak Prabowo dan Mas Gibran 🎉❤🇮🇩
# Kenapa pada protes ya.....bila perlu syaratnya usia 20 tahun...........kalaupun dia tidak kompeten ada rakyat bakal milih......kenapa pengen menang wo...
# Katanya negara demokrasi.....siapa aja yg masuk jadi pencalonan....ya kenapa di permasalahkan.....toh juga rakyat yg milih.......
# Demokrasi Indonesia mati
# Ganjar aja deh
# Katanya ngk bisa. Batas usia. Mana yg benar ia ??
# Emng jd ???
# tetep yakin Prabowo Gibran menang di putaran kedua
# 2024 untuk prabowo gibran
# Usianya paling sepuh adalah pilihan saya
# Ganjar,mahfud bos,  ora sudi pilih gibran
# Rakyat bener&quot; jijik dg caranya jadi cawapres
# Makanya mending coblos Prabowo aja
# Prabowo gibran akan gugur ini udah ingkar janji
# Gk akan jadi untuk slamanya
# Prabowo-Gibran tetap jadi R1, 🎉🎉🎉🎉
# Harusnya prabowo anies,tapi kalau begini mending anies cak imin
# Gak ngurus
# Lihat mukanya aja dah muak
# SEMOGA GAGAL, SAYA SELALU MENDUKUNG PAK PRABOWO TAPI SETELAH TAU ADA GIBRAN NYA HUH OGAH, PAK PAK HARUS NYA JANGAN GIBRAN LAH WAKILNYA
# iya bener
# Emang kenapa klw wakilnya Gibran,,??
# Mau tanya min ,gibran udah keluar blm dari pdip
# Cawapres aja bangga... Pilih dunk Prabowo capres...
# LANJUTKAN KEDUNGUAN KALIAN DGN KOMENTAR GIBAH.NYINYIR HUJAT.BOHONG &amp; FITNAH. MMG KALIAN PALING HEBAT. PALING BAIK. PALING SUKSES.TAPI BOONG🤣TAPI DUNGU🤣
# Blm jadi pemilu di jamin SDH kalah...amin Ganjar maju pinal
# KASIAN GANJAR KALO GAK ADA PDIP🤣 KASIAN ANIES KALO GAK ADA NASDEM🤣 ITULAH PETUGAS PARTAI🤣JADI SIAPA YG NGATUR NEGARA DAN RAKYATNYA? YA KETUA PARTAILAH. PRABOWO KETUA PARTAI GAK ADA YG BS MENDIKTE..
# Ogah bngt pilih Cawapres Karbitan  di Paksa . 😊
# Daripada pilih kelompok Durhaka Amin Rais Cak Imin Roki Gerung tu semua orang2 pembawa kesialan bagi capres yg didukungnya selalu keok nyungsep 🤣
# Ampassss
# Semangat nyoblos Prabowo Gibran untuk Indonesia maju
# Tim pemenangan prabowo<br>Aldi taher ,kiki, kaesang cakil , fadli zonk , fahri hamzah ,roki gerung , rizal ramli 😂
# Roki gerunk dan Amin Rais dukung Anies-Muhaimin 🤣
# Moal milih tetep anies
# Rais
# Tim pembela nepotisme
# Santai, casual, jos❤
# Tenang tenang pak MK MK wakkk🤪🤪🤪
# GIBRAN BUKAN KAKENG KALENG 25 RH ANAK JOKO W 35 TH CUCU KETUA ..SULAMI ASAL BOYOLALI
# 35 th
# @Oleh Soleh emil dardak kader demokrat wakil khofifah INDAR PARAWANGSA wakil gubernur Jawa Timur, gak lolos MK 😎 USIA 38 TAHUN.
# Terimakasih paman
# 2024 ALL IN PRABOWO GIBRAN ❤
# BALI MENANG TELAK PRAGIB INDONESIA EMAS 2024
# 100% ir soekarno masih PDIP bos 😎 liat berita ganjar pranowo di bali 😎
# Menangis bro g ada kartunya prabowo menang .
# Gibran sang penghianat...

# %%
clean_texts = []
token_texts = []
freq_words = []

# stopword
stop_factory = StopWordRemoverFactory().get_stop_words() #load defaul stopword
more_stopword = ['•',"stengah", "kopit", "china","g","yaaaaa","gengs","gada","dgn",
"nich","yg","padan", "juoro","nya","js","kl","","co","ga","lg","gw","jg","walu",
"grrabbpoodd","klo","jeben","makane","kakean","sek","mb","skp","tpi","bgt","lgi",
"lu","rb","rban","mura","pd","nih","lii","enel","dr","exo","ipo","trus","d","shm",
"skrg","byk","mang","ots","dah""dg","bp","n","arsjadrasjid","mmc"] #menambahkan stopword
data_stopword = stop_factory + more_stopword #menggabungkan stopword

for tweet in tqdm(df_cleaned['textDisplay']):
    tweet = re.sub("@[A-Za-z0-9]+","",tweet) #Remove @ sign
    tweet = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", tweet) #Remove http links
    tweet = tweet.replace("#", "").replace("_", " ") #Remove hashtag sign but keep the text
    tweet = re.sub(r"\d+", "", tweet) # Remove number
#     tweet = ''.join(c for c in tweet if c not in emoji.EMOJI_DATA) #Remove Emojis
    tweet = tweet.replace('"','') #remove quotation mark
    tweet = tweet.lower() #Lower Case
    tweet = tweet.strip() # Remove Whitespace
    tweet = tweet.translate(str.maketrans("","",string.punctuation)) #Remove Punctuation 
 
    dictionary = ArrayDictionary(data_stopword)
    swr = StopWordRemover(dictionary)
    tweet = swr.remove(tweet)
    
    #Tokenization
    tokens = nltk.tokenize.word_tokenize(tweet)
    tweet = " ".join(tokens) #Disatukan Kembali
    
    freq_words.append(nltk.FreqDist(word_tokenize(tweet)))
    
    token_texts.append(tokens)
    clean_texts.append(tweet)
df_cleaned['clear'] = clean_texts
df_cleaned['token_texts'] = token_texts
df_cleaned['freq_words'] = freq_words

all_freq_words = nltk.FreqDist(sum(df_cleaned['clear'].map(word_tokenize), []))

df_cleaned
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 374.21it/s]
# C:\Users\ICHSAM\AppData\Local\Temp\ipykernel_9808\565270061.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['clear'] = clean_texts
# C:\Users\ICHSAM\AppData\Local\Temp\ipykernel_9808\565270061.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['token_texts'] = token_texts
# C:\Users\ICHSAM\AppData\Local\Temp\ipykernel_9808\565270061.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['freq_words'] = freq_words
#              publishedAt        authorDisplayName  \
# 0   2023-11-04T02:02:00Z              umi kaimana
# 1   2023-11-03T23:17:05Z              Laode Handi
# 2   2023-11-03T22:39:48Z             Aris Santoso
# 3   2023-11-03T15:35:49Z                      AWU
# 4   2023-11-03T14:33:52Z           Gogolali Kroto
# 5   2023-11-03T14:16:19Z               G Hasibuan
# 6   2023-11-03T14:13:30Z               G Hasibuan
# 7   2023-11-03T09:53:26Z             Sahmal Bebie
# 8   2023-11-03T07:41:13Z             Mian Siahaan
# 9   2023-11-03T07:39:50Z             Mian Siahaan
# 10  2023-11-03T07:39:13Z             Mian Siahaan
# 11  2023-11-03T03:07:36Z           Designbyardans
# 12  2023-11-03T00:51:29Z            Lissa Hantono
# 13  2023-11-03T00:15:53Z              Yudhis Tira
# 14  2023-11-02T23:27:36Z              Robi Godean
# 15  2023-11-02T22:50:02Z             Rusdi Faisal
# 16  2023-11-03T14:13:44Z       pencari ketenangan
# 17  2023-11-02T19:38:32Z                  Purwadi
# 18  2023-11-02T19:37:29Z                  Purwadi
# 19  2023-11-02T18:19:33Z         Avanza Jual beli
# 20  2023-11-02T18:00:43Z              azid jajili
# 21  2023-11-02T16:25:00Z           Nurdiah Kristi
# 22  2023-11-02T14:56:41Z                Niko Danu
# 23  2023-11-02T14:28:12Z             @ANDRE MANIA
# 24  2023-11-03T08:41:05Z           Kewaige kyliee
# 25  2023-11-03T16:21:07Z                 VALE IJE
# 26  2023-11-02T14:12:26Z                Joy Rohli
# 29  2023-11-03T14:14:35Z       pencari ketenangan
# 30  2023-11-02T11:32:40Z              Jacky Aulia
# 31  2023-11-02T11:29:44Z            Pujiatmoko 77
# 32  2023-11-02T11:28:23Z              Jacky Aulia
# 33  2023-11-02T10:32:17Z              Alin jennie
# 34  2023-11-03T07:08:10Z              Salsa Micin
# 35  2023-11-02T10:29:05Z              Dedi Swandi
# 36  2023-11-02T10:25:23Z             Immunoterapi
# 37  2023-11-02T10:21:52Z                 Rudy . S
# 38  2023-11-03T07:12:40Z              Salsa Micin
# 39  2023-11-02T10:00:41Z                Enor Juni
# 40  2023-11-02T10:18:02Z         [ Kizuna Kaori ]
# 41  2023-11-02T09:49:33Z      Budipapabumi Hening
# 42  2023-11-02T09:47:40Z          Casper Himalaya
# 43  2023-11-02T09:29:32Z                        A
# 44  2023-11-02T09:24:10Z               Oleh Soleh
# 45  2023-11-02T09:24:37Z               Oleh Soleh
# 46  2023-11-02T09:40:45Z           Muhammad Rizal
# 47  2023-11-02T09:23:37Z             Stb Indihome
# 48  2023-11-02T09:08:31Z      Divide de' memories
# 49  2023-11-02T08:55:11Z  Deddy andrian Kurniawsn
# 50  2023-11-02T09:38:56Z           Muhammad Rizal
# 51  2023-11-02T09:46:16Z       MBNEM ROOSTER FARM
# 52  2023-11-02T08:40:55Z              Abboy Topan
#
#                                           textDisplay  likeCount  \
# 0   Mas Gibran pria mudah <br>Adalah generasi pene...        0.0
# 1   Prediksi saya Prabowo Gibran menang diatas 50 ...        0.0
# 2           Gibran kucluk gayane koyo baim wong......        0.0
# 3   Semenjak kalah terus jadi menhan jadi kaga res...        0.0
# 4     Mantap kali...  Pak Prabowo dan Mas Gibran 🎉❤🇮🇩        0.0
# 5   Kenapa pada protes ya.....bila perlu syaratnya...        0.0
# 6   Katanya negara demokrasi.....siapa aja yg masu...        0.0
# 7                            Demokrasi Indonesia mati        0.0
# 8                                      Ganjar aja deh        0.0
# 9   Katanya ngk bisa. Batas usia. Mana yg benar ia ??        1.0
# 10                                        Emng jd ???        0.0
# 11  tetep yakin Prabowo Gibran menang di putaran k...        2.0
# 12                          2024 untuk prabowo gibran        2.0
# 13           Usianya paling sepuh adalah pilihan saya        0.0
# 14          Ganjar,mahfud bos,  ora sudi pilih gibran        1.0
# 15  Rakyat bener&quot; jijik dg caranya jadi cawapres        2.0
# 16                 Makanya mending coblos Prabowo aja        0.0
# 17    Prabowo gibran akan gugur ini udah ingkar janji        0.0
# 18                        Gk akan jadi untuk slamanya        0.0
# 19                 Prabowo-Gibran tetap jadi R1, 🎉🎉🎉🎉        4.0
# 20  Harusnya prabowo anies,tapi kalau begini mendi...        1.0
# 21                                         Gak ngurus        0.0
# 22                         Lihat mukanya aja dah muak        0.0
# 23  SEMOGA GAGAL, SAYA SELALU MENDUKUNG PAK PRABOW...        3.0
# 24                                          iya bener        0.0
# 25               Emang kenapa klw wakilnya Gibran,,??        1.0
# 26    Mau tanya min ,gibran udah keluar blm dari pdip        0.0
# 29  Cawapres aja bangga... Pilih dunk Prabowo capr...        0.0
# 30  LANJUTKAN KEDUNGUAN KALIAN DGN KOMENTAR GIBAH....        0.0
# 31  Blm jadi pemilu di jamin SDH kalah...amin Ganj...        2.0
# 32  KASIAN GANJAR KALO GAK ADA PDIP🤣 KASIAN ANIES ...        0.0
# 33    Ogah bngt pilih Cawapres Karbitan  di Paksa . 😊       10.0
# 34  Daripada pilih kelompok Durhaka Amin Rais Cak ...        3.0
# 35                                           Ampassss        0.0
# 36  Semangat nyoblos Prabowo Gibran untuk Indonesi...        5.0
# 37  Tim pemenangan prabowo<br>Aldi taher ,kiki, ka...        6.0
# 38  Roki gerunk dan Amin Rais dukung Anies-Muhaimin 🤣        0.0
# 39                             Moal milih tetep anies        1.0
# 40                                               Rais        0.0
# 41                              Tim pembela nepotisme        4.0
# 42                               Santai, casual, jos❤        0.0
# 43                   Tenang tenang pak MK MK wakkk🤪🤪🤪        5.0
# 44  GIBRAN BUKAN KAKENG KALENG 25 RH ANAK JOKO W 3...        1.0
# 45                                              35 th        0.0
# 46  @Oleh Soleh emil dardak kader demokrat wakil k...        1.0
# 47                                  Terimakasih paman        4.0
# 48                       2024 ALL IN PRABOWO GIBRAN ❤       10.0
# 49       BALI MENANG TELAK PRAGIB INDONESIA EMAS 2024        6.0
# 50  100% ir soekarno masih PDIP bos 😎 liat berita ...        2.0
# 51       Menangis bro g ada kartunya prabowo menang .        0.0
# 52                          Gibran sang penghianat...        0.0
#
#                                                 clear  \
# 0   mas gibran pria mudah bradalah generasi peneru...
# 1   prediksi prabowo gibran menang diatas persen a...
# 2                 gibran kucluk gayane koyo baim wong
# 3   semenjak kalah terus jadi menhan jadi kaga res...
# 4             mantap kali pak prabowo mas gibran 🎉❤🇮🇩
# 5   pada protes yabila perlu syaratnya usia tahunk...
# 6   katanya negara demokrasisiapa aja masuk jadi p...
# 7                            demokrasi indonesia mati
# 8                                      ganjar aja deh
# 9                   katanya ngk batas usia mana benar
# 10                                            emng jd
# 11    tetep yakin prabowo gibran menang putaran kedua
# 12                                     prabowo gibran
# 13                       usianya paling sepuh pilihan
# 14             ganjarmahfud bos ora sudi pilih gibran
# 15    rakyat benerquot jijik dg caranya jadi cawapres
# 16                 makanya mending coblos prabowo aja
# 17             prabowo gibran gugur udah ingkar janji
# 18                                   gk jadi slamanya
# 19                    prabowogibran tetap jadi r 🎉🎉🎉🎉
# 20  harusnya prabowo aniestapi kalau begini mendin...
# 21                                         gak ngurus
# 22                         lihat mukanya aja dah muak
# 23  semoga gagal selalu mendukung pak prabowo sete...
# 24                                          iya bener
# 25                          emang klw wakilnya gibran
# 26          mau tanya min gibran udah keluar blm pdip
# 29      cawapres aja bangga pilih dunk prabowo capres
# 30  lanjutkan kedunguan kalian komentar gibahnyiny...
# 31  blm jadi pemilu jamin sdh kalahamin ganjar maj...
# 32  kasian ganjar kalo gak pdip🤣 kasian anies kalo...
# 33          ogah bngt pilih cawapres karbitan paksa 😊
# 34  pilih kelompok durhaka amin rais cak imin roki...
# 35                                           ampassss
# 36     semangat nyoblos prabowo gibran indonesia maju
# 37  tim pemenangan prabowobraldi taher kiki kaesan...
# 38       roki gerunk amin rais dukung aniesmuhaimin 🤣
# 39                             moal milih tetep anies
# 40                                               rais
# 41                              tim pembela nepotisme
# 42                                 santai casual jos❤
# 43                   tenang tenang pak mk mk wakkk🤪🤪🤪
# 44  gibran bukan kakeng kaleng rh anak joko w th c...
# 45                                                 th
# 46  soleh emil dardak kader demokrat wakil khofifa...
# 47                                  terimakasih paman
# 48                            all in prabowo gibran ❤
# 49            bali menang telak pragib indonesia emas
# 50  ir soekarno pdip bos 😎 liat berita ganjar pran...
# 51           menangis bro ada kartunya prabowo menang
# 52                             gibran sang penghianat
#
#                                           token_texts  \
# 0   [mas, gibran, pria, mudah, bradalah, generasi,...
# 1   [prediksi, prabowo, gibran, menang, diatas, pe...
# 2          [gibran, kucluk, gayane, koyo, baim, wong]
# 3   [semenjak, kalah, terus, jadi, menhan, jadi, k...
# 4     [mantap, kali, pak, prabowo, mas, gibran, 🎉❤🇮🇩]
# 5   [pada, protes, yabila, perlu, syaratnya, usia,...
# 6   [katanya, negara, demokrasisiapa, aja, masuk, ...
# 7                        [demokrasi, indonesia, mati]
# 8                                  [ganjar, aja, deh]
# 9            [katanya, ngk, batas, usia, mana, benar]
# 10                                         [emng, jd]
# 11  [tetep, yakin, prabowo, gibran, menang, putara...
# 12                                  [prabowo, gibran]
# 13                  [usianya, paling, sepuh, pilihan]
# 14      [ganjarmahfud, bos, ora, sudi, pilih, gibran]
# 15  [rakyat, benerquot, jijik, dg, caranya, jadi, ...
# 16           [makanya, mending, coblos, prabowo, aja]
# 17      [prabowo, gibran, gugur, udah, ingkar, janji]
# 18                               [gk, jadi, slamanya]
# 19              [prabowogibran, tetap, jadi, r, 🎉🎉🎉🎉]
# 20  [harusnya, prabowo, aniestapi, kalau, begini, ...
# 21                                      [gak, ngurus]
# 22                   [lihat, mukanya, aja, dah, muak]
# 23  [semoga, gagal, selalu, mendukung, pak, prabow...
# 24                                       [iya, bener]
# 25                     [emang, klw, wakilnya, gibran]
# 26  [mau, tanya, min, gibran, udah, keluar, blm, p...
# 29  [cawapres, aja, bangga, pilih, dunk, prabowo, ...
# 30  [lanjutkan, kedunguan, kalian, komentar, gibah...
# 31  [blm, jadi, pemilu, jamin, sdh, kalahamin, gan...
# 32  [kasian, ganjar, kalo, gak, pdip🤣, kasian, ani...
# 33  [ogah, bngt, pilih, cawapres, karbitan, paksa, 😊]
# 34  [pilih, kelompok, durhaka, amin, rais, cak, im...
# 35                                         [ampassss]
# 36  [semangat, nyoblos, prabowo, gibran, indonesia...
# 37  [tim, pemenangan, prabowobraldi, taher, kiki, ...
# 38  [roki, gerunk, amin, rais, dukung, aniesmuhaim...
# 39                        [moal, milih, tetep, anies]
# 40                                             [rais]
# 41                          [tim, pembela, nepotisme]
# 42                             [santai, casual, jos❤]
# 43            [tenang, tenang, pak, mk, mk, wakkk🤪🤪🤪]
# 44  [gibran, bukan, kakeng, kaleng, rh, anak, joko...
# 45                                               [th]
# 46  [soleh, emil, dardak, kader, demokrat, wakil, ...
# 47                               [terimakasih, paman]
# 48                      [all, in, prabowo, gibran, ❤]
# 49     [bali, menang, telak, pragib, indonesia, emas]
# 50  [ir, soekarno, pdip, bos, 😎, liat, berita, gan...
# 51    [menangis, bro, ada, kartunya, prabowo, menang]
# 52                         [gibran, sang, penghianat]
#
#                                            freq_words
# 0   {'mas': 1, 'gibran': 2, 'pria': 1, 'mudah': 1,...
# 1   {'prediksi': 1, 'prabowo': 1, 'gibran': 2, 'me...
# 2   {'gibran': 1, 'kucluk': 1, 'gayane': 1, 'koyo'...
# 3   {'semenjak': 1, 'kalah': 1, 'terus': 1, 'jadi'...
# 4   {'mantap': 1, 'kali': 1, 'pak': 1, 'prabowo': ...
# 5   {'pada': 1, 'protes': 1, 'yabila': 1, 'perlu':...
# 6   {'katanya': 1, 'negara': 1, 'demokrasisiapa': ...
# 7         {'demokrasi': 1, 'indonesia': 1, 'mati': 1}
# 8                   {'ganjar': 1, 'aja': 1, 'deh': 1}
# 9   {'katanya': 1, 'ngk': 1, 'batas': 1, 'usia': 1...
# 10                               {'emng': 1, 'jd': 1}
# 11  {'tetep': 1, 'yakin': 1, 'prabowo': 1, 'gibran...
# 12                        {'prabowo': 1, 'gibran': 1}
# 13  {'usianya': 1, 'paling': 1, 'sepuh': 1, 'pilih...
# 14  {'ganjarmahfud': 1, 'bos': 1, 'ora': 1, 'sudi'...
# 15  {'rakyat': 1, 'benerquot': 1, 'jijik': 1, 'dg'...
# 16  {'makanya': 1, 'mending': 1, 'coblos': 1, 'pra...
# 17  {'prabowo': 1, 'gibran': 1, 'gugur': 1, 'udah'...
# 18                {'gk': 1, 'jadi': 1, 'slamanya': 1}
# 19  {'prabowogibran': 1, 'tetap': 1, 'jadi': 1, 'r...
# 20  {'harusnya': 1, 'prabowo': 1, 'aniestapi': 1, ...
# 21                            {'gak': 1, 'ngurus': 1}
# 22  {'lihat': 1, 'mukanya': 1, 'aja': 1, 'dah': 1,...
# 23  {'semoga': 1, 'gagal': 1, 'selalu': 1, 'menduk...
# 24                             {'iya': 1, 'bener': 1}
# 25  {'emang': 1, 'klw': 1, 'wakilnya': 1, 'gibran'...
# 26  {'mau': 1, 'tanya': 1, 'min': 1, 'gibran': 1, ...
# 29  {'cawapres': 1, 'aja': 1, 'bangga': 1, 'pilih'...
# 30  {'lanjutkan': 1, 'kedunguan': 1, 'kalian': 2, ...
# 31  {'blm': 1, 'jadi': 1, 'pemilu': 1, 'jamin': 1,...
# 32  {'kasian': 2, 'ganjar': 1, 'kalo': 2, 'gak': 3...
# 33  {'ogah': 1, 'bngt': 1, 'pilih': 1, 'cawapres':...
# 34  {'pilih': 1, 'kelompok': 1, 'durhaka': 1, 'ami...
# 35                                    {'ampassss': 1}
# 36  {'semangat': 1, 'nyoblos': 1, 'prabowo': 1, 'g...
# 37  {'tim': 1, 'pemenangan': 1, 'prabowobraldi': 1...
# 38  {'roki': 1, 'gerunk': 1, 'amin': 1, 'rais': 1,...
# 39    {'moal': 1, 'milih': 1, 'tetep': 1, 'anies': 1}
# 40                                        {'rais': 1}
# 41           {'tim': 1, 'pembela': 1, 'nepotisme': 1}
# 42              {'santai': 1, 'casual': 1, 'jos❤': 1}
# 43    {'tenang': 2, 'pak': 1, 'mk': 2, 'wakkk🤪🤪🤪': 1}
# 44  {'gibran': 1, 'bukan': 1, 'kakeng': 1, 'kaleng...
# 45                                          {'th': 1}
# 46  {'soleh': 1, 'emil': 1, 'dardak': 1, 'kader': ...
# 47                     {'terimakasih': 1, 'paman': 1}
# 48  {'all': 1, 'in': 1, 'prabowo': 1, 'gibran': 1,...
# 49  {'bali': 1, 'menang': 1, 'telak': 1, 'pragib':...
# 50  {'ir': 1, 'soekarno': 1, 'pdip': 1, 'bos': 1, ...
# 51  {'menangis': 1, 'bro': 1, 'ada': 1, 'kartunya'...
# 52          {'gibran': 1, 'sang': 1, 'penghianat': 1}

# %%
# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df_cleaned['token_texts']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df_cleaned['stemmed_texts'] = df_cleaned['token_texts'].swifter.apply(get_stemmed_term)
print(df_cleaned['stemmed_texts'])
# Out:
# 281
# ------------------------
# mas : mas
# gibran : gibran
# pria : pria
# mudah : mudah
# bradalah : bradalah
# generasi : generasi
# penerusbryg : penerusbryg
# mementingkan : penting
# kepetinganbrgolongan : kepetinganbrgolongan
# dripd : dripd
# kepentingan : penting
# pribadimas : pribadimas
# maju : maju
# terus : terus
# prediksi : prediksi
# prabowo : prabowo
# menang : menang
# diatas : atas
# persen : persen
# alasan : alas
# pemilih : pilih
# prabowopemilih : prabowopemilih
# sby : sby
# relawan : rawan
# mesin : mesin
# koalsi : koalsi
# indo : indo
# majukeluarga : majukeluarga
# soehartokel : soehartokel
# purnawirawankel : purnawirawankel
# diberi : beri
# bea : bea
# siswa : siswa
# kucluk : kucluk
# gayane : gayane
# koyo : koyo
# baim : baim
# wong : wong
# semenjak : semenjak
# kalah : kalah
# jadi : jadi
# menhan : menhan
# kaga : kaga
# resep : resep
# udah : udah
# brmending : brmending
# anies : anies
# lah : lah
# mantap : mantap
# kali : kali
# pak : pak
# 🎉❤🇮🇩 :
# pada : pada
# protes : protes
# yabila : yabila
# perlu : perlu
# syaratnya : syarat
# usia : usia
# tahunkalaupun : tahunkalaupun
# tidak : tidak
# kompeten : kompeten
# rakyat : rakyat
# bakal : bakal
# milihkenapa : milihkenapa
# pengen : ken
# wo : wo
# katanya : kata
# negara : negara
# demokrasisiapa : demokrasisiapa
# aja : aja
# masuk : masuk
# pencalonanya : pencalonanya
# di : di
# permasalahkantoh : permasalahkantoh
# milih : milih
# demokrasi : demokrasi
# indonesia : indonesia
# mati : mati
# ganjar : ganjar
# deh : deh
# ngk : ngk
# batas : batas
# mana : mana
# benar : benar
# emng : emng
# jd : jd
# tetep : tetep
# yakin : yakin
# putaran : putar
# kedua : dua
# usianya : usia
# paling : paling
# sepuh : sepuh
# pilihan : pilih
# ganjarmahfud : ganjarmahfud
# bos : bos
# ora : ora
# sudi : sudi
# pilih : pilih
# benerquot : benerquot
# jijik : jijik
# dg : dg
# caranya : cara
# cawapres : cawapres
# makanya : makanya
# mending : mending
# coblos : coblos
# gugur : gugur
# ingkar : ingkar
# janji : janji
# gk : gk
# slamanya : slamanya
# prabowogibran : prabowogibran
# tetap : tetap
# r : r
# 🎉🎉🎉🎉 :
# harusnya : harus
# aniestapi : aniestapi
# kalau : kalau
# begini : begini
# cak : cak
# imin : imin
# gak : gak
# ngurus : ngurus
# lihat : lihat
# mukanya : muka
# dah : dah
# muak : muak
# semoga : moga
# gagal : gagal
# selalu : selalu
# mendukung : dukung
# setelah : telah
# tau : tau
# huh : huh
# ogah : ogah
# nya : nya
# jangan : jangan
# wakilnya : wakil
# iya : iya
# bener : bener
# emang : emang
# klw : klw
# mau : mau
# tanya : tanya
# min : min
# keluar : keluar
# blm : blm
# pdip : pdip
# bangga : bangga
# dunk : dunk
# capres : capres
# lanjutkan : lanjut
# kedunguan : dungu
# kalian : kalian
# komentar : komentar
# gibahnyinyir : gibahnyinyir
# hujatbohong : hujatbohong
# amp : amp
# fitnah : fitnah
# mmg : mmg
# hebat : hebat
# baik : baik
# suksestapi : suksestapi
# boong🤣tapi : boong tapi
# dungu🤣 : dungu
# pemilu : milu
# jamin : jamin
# sdh : sdh
# kalahamin : kalahamin
# pinal : pal
# kasian : kasi
# kalo : kalo
# pdip🤣 : pdip
# nasdem🤣 : nasdem
# petugas : tugas
# partai🤣jadi : partai jadi
# siapa : siapa
# ngatur : ngatur
# rakyatnya : rakyat
# ketua : ketua
# partailah : partai
# partai : partai
# yg : yg
# bs : bs
# mendikte : dikte
# bngt : bngt
# karbitan : karbitan
# paksa : paksa
# 😊 :
# kelompok : kelompok
# durhaka : durhaka
# amin : amin
# rais : rais
# roki : roki
# gerung : gerung
# tu : tu
# semua : semua
# orang : orang
# pembawa : bawa
# kesialan : sial
# didukungnya : dukung
# keok : keok
# nyungsep : nyungsep
# 🤣 :
# ampassss : ampassss
# semangat : semangat
# nyoblos : nyoblos
# tim : tim
# pemenangan : menang
# prabowobraldi : prabowobraldi
# taher : taher
# kiki : kiki
# kaesang : kaesang
# cakil : cakil
# fadli : fadli
# zonk : zonk
# fahri : fahri
# hamzah : hamzah
# rizal : rizal
# ramli : ramli
# 😂 :
# gerunk : gerunk
# dukung : dukung
# aniesmuhaimin : aniesmuhaimin
# moal : moal
# pembela : bela
# nepotisme : nepotisme
# santai : santai
# casual : casual
# jos❤ : jos
# tenang : tenang
# mk : mk
# wakkk🤪🤪🤪 : wakkk
# bukan : bukan
# kakeng : kakeng
# kaleng : kaleng
# rh : rh
# anak : anak
# joko : joko
# w : w
# th : th
# cucu : cucu
# sulami : sulam
# asal : asal
# boyolali : boyolali
# soleh : soleh
# emil : emil
# dardak : dardak
# kader : kader
# demokrat : demokrat
# wakil : wakil
# khofifah : khofifah
# indar : indar
# parawangsa : parawangsa
# gubernur : gubernur
# jawa : jawa
# timur : timur
# lolos : lolos
# 😎 :
# tahun : tahun
# terimakasih : terimakasih
# paman : paman
# all : all
# in : in
# ❤ :
# bali : bal
# telak : telak
# pragib : pragib
# emas : emas
# ir : ir
# soekarno : soekarno
# liat : liat
# berita : berita
# pranowo : pranowo
# menangis : menang
# bro : bro
# ada : ada
# kartunya : kartu
# sang : sang
# penghianat : penghianat
# {'mas': 'mas', 'gibran': 'gibran', 'pria': 'pria', 'mudah': 'mudah', 'bradalah': 'bradalah', 'generasi': 'generasi', 'penerusbryg': 'penerusbryg', 'mementingkan': 'penting', 'kepetinganbrgolongan': 'kepetinganbrgolongan', 'dripd': 'dripd', 'kepentingan': 'penting', 'pribadimas': 'pribadimas', 'maju': 'maju', 'terus': 'terus', 'prediksi': 'prediksi', 'prabowo': 'prabowo', 'menang': 'menang', 'diatas': 'atas', 'persen': 'persen', 'alasan': 'alas', 'pemilih': 'pilih', 'prabowopemilih': 'prabowopemilih', 'sby': 'sby', 'relawan': 'rawan', 'mesin': 'mesin', 'koalsi': 'koalsi', 'indo': 'indo', 'majukeluarga': 'majukeluarga', 'soehartokel': 'soehartokel', 'purnawirawankel': 'purnawirawankel', 'diberi': 'beri', 'bea': 'bea', 'siswa': 'siswa', 'kucluk': 'kucluk', 'gayane': 'gayane', 'koyo': 'koyo', 'baim': 'baim', 'wong': 'wong', 'semenjak': 'semenjak', 'kalah': 'kalah', 'jadi': 'jadi', 'menhan': 'menhan', 'kaga': 'kaga', 'resep': 'resep', 'udah': 'udah', 'brmending': 'brmending', 'anies': 'anies', 'lah': 'lah', 'mantap': 'mantap', 'kali': 'kali', 'pak': 'pak', '🎉❤🇮🇩': '', 'pada': 'pada', 'protes': 'protes', 'yabila': 'yabila', 'perlu': 'perlu', 'syaratnya': 'syarat', 'usia': 'usia', 'tahunkalaupun': 'tahunkalaupun', 'tidak': 'tidak', 'kompeten': 'kompeten', 'rakyat': 'rakyat', 'bakal': 'bakal', 'milihkenapa': 'milihkenapa', 'pengen': 'ken', 'wo': 'wo', 'katanya': 'kata', 'negara': 'negara', 'demokrasisiapa': 'demokrasisiapa', 'aja': 'aja', 'masuk': 'masuk', 'pencalonanya': 'pencalonanya', 'di': 'di', 'permasalahkantoh': 'permasalahkantoh', 'milih': 'milih', 'demokrasi': 'demokrasi', 'indonesia': 'indonesia', 'mati': 'mati', 'ganjar': 'ganjar', 'deh': 'deh', 'ngk': 'ngk', 'batas': 'batas', 'mana': 'mana', 'benar': 'benar', 'emng': 'emng', 'jd': 'jd', 'tetep': 'tetep', 'yakin': 'yakin', 'putaran': 'putar', 'kedua': 'dua', 'usianya': 'usia', 'paling': 'paling', 'sepuh': 'sepuh', 'pilihan': 'pilih', 'ganjarmahfud': 'ganjarmahfud', 'bos': 'bos', 'ora': 'ora', 'sudi': 'sudi', 'pilih': 'pilih', 'benerquot': 'benerquot', 'jijik': 'jijik', 'dg': 'dg', 'caranya': 'cara', 'cawapres': 'cawapres', 'makanya': 'makanya', 'mending': 'mending', 'coblos': 'coblos', 'gugur': 'gugur', 'ingkar': 'ingkar', 'janji': 'janji', 'gk': 'gk', 'slamanya': 'slamanya', 'prabowogibran': 'prabowogibran', 'tetap': 'tetap', 'r': 'r', '🎉🎉🎉🎉': '', 'harusnya': 'harus', 'aniestapi': 'aniestapi', 'kalau': 'kalau', 'begini': 'begini', 'cak': 'cak', 'imin': 'imin', 'gak': 'gak', 'ngurus': 'ngurus', 'lihat': 'lihat', 'mukanya': 'muka', 'dah': 'dah', 'muak': 'muak', 'semoga': 'moga', 'gagal': 'gagal', 'selalu': 'selalu', 'mendukung': 'dukung', 'setelah': 'telah', 'tau': 'tau', 'huh': 'huh', 'ogah': 'ogah', 'nya': 'nya', 'jangan': 'jangan', 'wakilnya': 'wakil', 'iya': 'iya', 'bener': 'bener', 'emang': 'emang', 'klw': 'klw', 'mau': 'mau', 'tanya': 'tanya', 'min': 'min', 'keluar': 'keluar', 'blm': 'blm', 'pdip': 'pdip', 'bangga': 'bangga', 'dunk': 'dunk', 'capres': 'capres', 'lanjutkan': 'lanjut', 'kedunguan': 'dungu', 'kalian': 'kalian', 'komentar': 'komentar', 'gibahnyinyir': 'gibahnyinyir', 'hujatbohong': 'hujatbohong', 'amp': 'amp', 'fitnah': 'fitnah', 'mmg': 'mmg', 'hebat': 'hebat', 'baik': 'baik', 'suksestapi': 'suksestapi', 'boong🤣tapi': 'boong tapi', 'dungu🤣': 'dungu', 'pemilu': 'milu', 'jamin': 'jamin', 'sdh': 'sdh', 'kalahamin': 'kalahamin', 'pinal': 'pal', 'kasian': 'kasi', 'kalo': 'kalo', 'pdip🤣': 'pdip', 'nasdem🤣': 'nasdem', 'petugas': 'tugas', 'partai🤣jadi': 'partai jadi', 'siapa': 'siapa', 'ngatur': 'ngatur', 'rakyatnya': 'rakyat', 'ketua': 'ketua', 'partailah': 'partai', 'partai': 'partai', 'yg': 'yg', 'bs': 'bs', 'mendikte': 'dikte', 'bngt': 'bngt', 'karbitan': 'karbitan', 'paksa': 'paksa', '😊': '', 'kelompok': 'kelompok', 'durhaka': 'durhaka', 'amin': 'amin', 'rais': 'rais', 'roki': 'roki', 'gerung': 'gerung', 'tu': 'tu', 'semua': 'semua', 'orang': 'orang', 'pembawa': 'bawa', 'kesialan': 'sial', 'didukungnya': 'dukung', 'keok': 'keok', 'nyungsep': 'nyungsep', '🤣':  ...
# ------------------------
# Pandas Apply:   0%|          | 0/51 [00:00<?, ?it/s]
# 0     [mas, gibran, pria, mudah, bradalah, generasi,...
# 1     [prediksi, prabowo, gibran, menang, atas, pers...
# 2            [gibran, kucluk, gayane, koyo, baim, wong]
# 3     [semenjak, kalah, terus, jadi, menhan, jadi, k...
# 4           [mantap, kali, pak, prabowo, mas, gibran, ]
# 5     [pada, protes, yabila, perlu, syarat, usia, ta...
# 6     [kata, negara, demokrasisiapa, aja, masuk, jad...
# 7                          [demokrasi, indonesia, mati]
# 8                                    [ganjar, aja, deh]
# 9                 [kata, ngk, batas, usia, mana, benar]
# 10                                           [emng, jd]
# 11    [tetep, yakin, prabowo, gibran, menang, putar,...
# 12                                    [prabowo, gibran]
# 13                         [usia, paling, sepuh, pilih]
# 14        [ganjarmahfud, bos, ora, sudi, pilih, gibran]
# 15    [rakyat, benerquot, jijik, dg, cara, jadi, caw...
# 16             [makanya, mending, coblos, prabowo, aja]
# 17        [prabowo, gibran, gugur, udah, ingkar, janji]
# 18                                 [gk, jadi, slamanya]
# 19                    [prabowogibran, tetap, jadi, r, ]
# 20    [harus, prabowo, aniestapi, kalau, begini, men...
# 21                                        [gak, ngurus]
# 22                        [lihat, muka, aja, dah, muak]
# 23    [moga, gagal, selalu, dukung, pak, prabowo, te...
# 24                                         [iya, bener]
# 25                          [emang, klw, wakil, gibran]
# 26    [mau, tanya, min, gibran, udah, keluar, blm, p...
# 29    [cawapres, aja, bangga, pilih, dunk, prabowo, ...
# 30    [lanjut, dungu, kalian, komentar, gibahnyinyir...
# 31    [blm, jadi, milu, jamin, sdh, kalahamin, ganja...
# 32    [kasi, ganjar, kalo, gak, pdip, kasi, anies, k...
# 33     [ogah, bngt, pilih, cawapres, karbitan, paksa, ]
# 34    [pilih, kelompok, durhaka, amin, rais, cak, im...
# 35                                           [ampassss]
# 36    [semangat, nyoblos, prabowo, gibran, indonesia...
# 37    [tim, menang, prabowobraldi, taher, kiki, kaes...
# 38    [roki, gerunk, amin, rais, dukung, aniesmuhaim...
# 39                          [moal, milih, tetep, anies]
# 40                                               [rais]
# 41                               [tim, bela, nepotisme]
# 42                                [santai, casual, jos]
# 43                 [tenang, tenang, pak, mk, mk, wakkk]
# 44    [gibran, bukan, kakeng, kaleng, rh, anak, joko...
# 45                                                 [th]
# 46    [soleh, emil, dardak, kader, demokrat, wakil, ...
# 47                                 [terimakasih, paman]
# 48                         [all, in, prabowo, gibran, ]
# 49        [bal, menang, telak, pragib, indonesia, emas]
# 50    [ir, soekarno, pdip, bos, , liat, berita, ganj...
# 51           [menang, bro, ada, kartu, prabowo, menang]
# 52                           [gibran, sang, penghianat]
# Name: stemmed_texts, dtype: object
# C:\Users\ICHSAM\AppData\Local\Temp\ipykernel_9808\2283960126.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['stemmed_texts'] = df_cleaned['token_texts'].swifter.apply(get_stemmed_term)

# %%
FreqWord = pd.DataFrame(all_freq_words.items(), columns=['word', 'frequency']).sort_values(by='frequency', ascending=False)

# %%
FreqWord
# Out:
#               word  frequency
# 1           gibran         18
# 15         prabowo         13
# 40            jadi          7
# 122            gak          5
# 50             pak          5
# ..             ...        ...
# 110             gk          1
# 111       slamanya          1
# 112  prabowogibran          1
# 113          tetap          1
# 280     penghianat          1
#
# [281 rows x 2 columns]

# %%
dfc.shape
dfc.isnull().sum()
dfc['clear'].isnull().sum()
df_final = dfc.drop(dfc[dfc.clear == ''].index)
dfc["clear"].duplicated().sum()
df_final.drop_duplicates(subset='clear',inplace=True)
df_final.shape

# %%
df_final = df_cleaned.copy()

# %%
df_cleaned.shape
# Out:
# (51, 8)

# %%
df_cleaned.isnull().sum()
# Out:
# publishedAt          0
# authorDisplayName    0
# textDisplay          0
# likeCount            0
# clear                0
# token_texts          0
# freq_words           0
# stemmed_texts        0
# dtype: int64

# %%
df_cleaned['clear'].isnull().sum()
# Out:
# 0

# %%
df_final = df_cleaned.drop(df_cleaned[df_cleaned.clear == ''].index)

# %%
df_cleaned["clear"].duplicated().sum()
# Out:
# 0

# %%
df_final.drop_duplicates(subset='clear',inplace=True)

# %%
df_cleaned.shape
# Out:
# (51, 8)

# %%
from textblob import TextBlob

# %%
translate_texts = []
label_texts = []
polarity_text = []
subjectivity_texts = []
scores=[]
for comment in tqdm(df_final['clear']):
    blob = TextBlob(comment)

    # Menerjemahkan teks ke Bahasa Inggris
#     terjemahan_inggris = blob.translate(from_lang='id', to='en')
    
    terjemahan_inggris=GoogleTranslator(source='auto', target='en').translate(comment)
    terjemahan_inggris=TextBlob(terjemahan_inggris)
    
    # Melakukan analisis sentimen
    sentimen = terjemahan_inggris.sentiment
    
    # Mendapatkan nilai sentimen
    polarity = sentimen.polarity  # Nilai antara -1 hingga 1 (positif hingga negatif)
    subjectivity = sentimen.subjectivity  # Nilai antara 0 hingga 1 (faktual hingga subjektif)

    # Menampilkan hasil analisis sentimen
    if polarity > 0:
        sentiment_label = "Positif"
        score=1
    elif polarity < 0:
        sentiment_label = "Negatif"
        score=-1
    else:
        sentiment_label = "Netral"
        score=0

#     print("Teks:", terjemahan_inggris.string)
    scores.append(score)
    label_texts.append(sentiment_label)
    polarity_text.append(polarity)
    translate_texts.append(terjemahan_inggris.string)
    subjectivity_texts.append(subjectivity)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 51/51 [01:26<00:00,  1.71s/it]

# %%
df_final['label']=label_texts
df_final['score']=scores
df_final['translate']=translate_texts
df_final['polarity']=polarity_text
df_final['subjectivity']=subjectivity_texts

# %%
df_final
# Out:
#              publishedAt        authorDisplayName  \
# 0   2023-11-04T02:02:00Z              umi kaimana
# 1   2023-11-03T23:17:05Z              Laode Handi
# 2   2023-11-03T22:39:48Z             Aris Santoso
# 3   2023-11-03T15:35:49Z                      AWU
# 4   2023-11-03T14:33:52Z           Gogolali Kroto
# 5   2023-11-03T14:16:19Z               G Hasibuan
# 6   2023-11-03T14:13:30Z               G Hasibuan
# 7   2023-11-03T09:53:26Z             Sahmal Bebie
# 8   2023-11-03T07:41:13Z             Mian Siahaan
# 9   2023-11-03T07:39:50Z             Mian Siahaan
# 10  2023-11-03T07:39:13Z             Mian Siahaan
# 11  2023-11-03T03:07:36Z           Designbyardans
# 12  2023-11-03T00:51:29Z            Lissa Hantono
# 13  2023-11-03T00:15:53Z              Yudhis Tira
# 14  2023-11-02T23:27:36Z              Robi Godean
# 15  2023-11-02T22:50:02Z             Rusdi Faisal
# 16  2023-11-03T14:13:44Z       pencari ketenangan
# 17  2023-11-02T19:38:32Z                  Purwadi
# 18  2023-11-02T19:37:29Z                  Purwadi
# 19  2023-11-02T18:19:33Z         Avanza Jual beli
# 20  2023-11-02T18:00:43Z              azid jajili
# 21  2023-11-02T16:25:00Z           Nurdiah Kristi
# 22  2023-11-02T14:56:41Z                Niko Danu
# 23  2023-11-02T14:28:12Z             @ANDRE MANIA
# 24  2023-11-03T08:41:05Z           Kewaige kyliee
# 25  2023-11-03T16:21:07Z                 VALE IJE
# 26  2023-11-02T14:12:26Z                Joy Rohli
# 29  2023-11-03T14:14:35Z       pencari ketenangan
# 30  2023-11-02T11:32:40Z              Jacky Aulia
# 31  2023-11-02T11:29:44Z            Pujiatmoko 77
# 32  2023-11-02T11:28:23Z              Jacky Aulia
# 33  2023-11-02T10:32:17Z              Alin jennie
# 34  2023-11-03T07:08:10Z              Salsa Micin
# 35  2023-11-02T10:29:05Z              Dedi Swandi
# 36  2023-11-02T10:25:23Z             Immunoterapi
# 37  2023-11-02T10:21:52Z                 Rudy . S
# 38  2023-11-03T07:12:40Z              Salsa Micin
# 39  2023-11-02T10:00:41Z                Enor Juni
# 40  2023-11-02T10:18:02Z         [ Kizuna Kaori ]
# 41  2023-11-02T09:49:33Z      Budipapabumi Hening
# 42  2023-11-02T09:47:40Z          Casper Himalaya
# 43  2023-11-02T09:29:32Z                        A
# 44  2023-11-02T09:24:10Z               Oleh Soleh
# 45  2023-11-02T09:24:37Z               Oleh Soleh
# 46  2023-11-02T09:40:45Z           Muhammad Rizal
# 47  2023-11-02T09:23:37Z             Stb Indihome
# 48  2023-11-02T09:08:31Z      Divide de' memories
# 49  2023-11-02T08:55:11Z  Deddy andrian Kurniawsn
# 50  2023-11-02T09:38:56Z           Muhammad Rizal
# 51  2023-11-02T09:46:16Z       MBNEM ROOSTER FARM
# 52  2023-11-02T08:40:55Z              Abboy Topan
#
#                                           textDisplay  likeCount  \
# 0   Mas Gibran pria mudah <br>Adalah generasi pene...        0.0
# 1   Prediksi saya Prabowo Gibran menang diatas 50 ...        0.0
# 2           Gibran kucluk gayane koyo baim wong......        0.0
# 3   Semenjak kalah terus jadi menhan jadi kaga res...        0.0
# 4     Mantap kali...  Pak Prabowo dan Mas Gibran 🎉❤🇮🇩        0.0
# 5   Kenapa pada protes ya.....bila perlu syaratnya...        0.0
# 6   Katanya negara demokrasi.....siapa aja yg masu...        0.0
# 7                            Demokrasi Indonesia mati        0.0
# 8                                      Ganjar aja deh        0.0
# 9   Katanya ngk bisa. Batas usia. Mana yg benar ia ??        1.0
# 10                                        Emng jd ???        0.0
# 11  tetep yakin Prabowo Gibran menang di putaran k...        2.0
# 12                          2024 untuk prabowo gibran        2.0
# 13           Usianya paling sepuh adalah pilihan saya        0.0
# 14          Ganjar,mahfud bos,  ora sudi pilih gibran        1.0
# 15  Rakyat bener&quot; jijik dg caranya jadi cawapres        2.0
# 16                 Makanya mending coblos Prabowo aja        0.0
# 17    Prabowo gibran akan gugur ini udah ingkar janji        0.0
# 18                        Gk akan jadi untuk slamanya        0.0
# 19                 Prabowo-Gibran tetap jadi R1, 🎉🎉🎉🎉        4.0
# 20  Harusnya prabowo anies,tapi kalau begini mendi...        1.0
# 21                                         Gak ngurus        0.0
# 22                         Lihat mukanya aja dah muak        0.0
# 23  SEMOGA GAGAL, SAYA SELALU MENDUKUNG PAK PRABOW...        3.0
# 24                                          iya bener        0.0
# 25               Emang kenapa klw wakilnya Gibran,,??        1.0
# 26    Mau tanya min ,gibran udah keluar blm dari pdip        0.0
# 29  Cawapres aja bangga... Pilih dunk Prabowo capr...        0.0
# 30  LANJUTKAN KEDUNGUAN KALIAN DGN KOMENTAR GIBAH....        0.0
# 31  Blm jadi pemilu di jamin SDH kalah...amin Ganj...        2.0
# 32  KASIAN GANJAR KALO GAK ADA PDIP🤣 KASIAN ANIES ...        0.0
# 33    Ogah bngt pilih Cawapres Karbitan  di Paksa . 😊       10.0
# 34  Daripada pilih kelompok Durhaka Amin Rais Cak ...        3.0
# 35                                           Ampassss        0.0
# 36  Semangat nyoblos Prabowo Gibran untuk Indonesi...        5.0
# 37  Tim pemenangan prabowo<br>Aldi taher ,kiki, ka...        6.0
# 38  Roki gerunk dan Amin Rais dukung Anies-Muhaimin 🤣        0.0
# 39                             Moal milih tetep anies        1.0
# 40                                               Rais        0.0
# 41                              Tim pembela nepotisme        4.0
# 42                               Santai, casual, jos❤        0.0
# 43                   Tenang tenang pak MK MK wakkk🤪🤪🤪        5.0
# 44  GIBRAN BUKAN KAKENG KALENG 25 RH ANAK JOKO W 3...        1.0
# 45                                              35 th        0.0
# 46  @Oleh Soleh emil dardak kader demokrat wakil k...        1.0
# 47                                  Terimakasih paman        4.0
# 48                       2024 ALL IN PRABOWO GIBRAN ❤       10.0
# 49       BALI MENANG TELAK PRAGIB INDONESIA EMAS 2024        6.0
# 50  100% ir soekarno masih PDIP bos 😎 liat berita ...        2.0
# 51       Menangis bro g ada kartunya prabowo menang .        0.0
# 52                          Gibran sang penghianat...        0.0
#
#                                                 clear  \
# 0   mas gibran pria mudah bradalah generasi peneru...
# 1   prediksi prabowo gibran menang diatas persen a...
# 2                 gibran kucluk gayane koyo baim wong
# 3   semenjak kalah terus jadi menhan jadi kaga res...
# 4             mantap kali pak prabowo mas gibran 🎉❤🇮🇩
# 5   pada protes yabila perlu syaratnya usia tahunk...
# 6   katanya negara demokrasisiapa aja masuk jadi p...
# 7                            demokrasi indonesia mati
# 8                                      ganjar aja deh
# 9                   katanya ngk batas usia mana benar
# 10                                            emng jd
# 11    tetep yakin prabowo gibran menang putaran kedua
# 12                                     prabowo gibran
# 13                       usianya paling sepuh pilihan
# 14             ganjarmahfud bos ora sudi pilih gibran
# 15    rakyat benerquot jijik dg caranya jadi cawapres
# 16                 makanya mending coblos prabowo aja
# 17             prabowo gibran gugur udah ingkar janji
# 18                                   gk jadi slamanya
# 19                    prabowogibran tetap jadi r 🎉🎉🎉🎉
# 20  harusnya prabowo aniestapi kalau begini mendin...
# 21                                         gak ngurus
# 22                         lihat mukanya aja dah muak
# 23  semoga gagal selalu mendukung pak prabowo sete...
# 24                                          iya bener
# 25                          emang klw wakilnya gibran
# 26          mau tanya min gibran udah keluar blm pdip
# 29      cawapres aja bangga pilih dunk prabowo capres
# 30  lanjutkan kedunguan kalian komentar gibahnyiny...
# 31  blm jadi pemilu jamin sdh kalahamin ganjar maj...
# 32  kasian ganjar kalo gak pdip🤣 kasian anies kalo...
# 33          ogah bngt pilih cawapres karbitan paksa 😊
# 34  pilih kelompok durhaka amin rais cak imin roki...
# 35                                           ampassss
# 36     semangat nyoblos prabowo gibran indonesia maju
# 37  tim pemenangan prabowobraldi taher kiki kaesan...
# 38       roki gerunk amin rais dukung aniesmuhaimin 🤣
# 39                             moal milih tetep anies
# 40                                               rais
# 41                              tim pembela nepotisme
# 42                                 santai casual jos❤
# 43                   tenang tenang pak mk mk wakkk🤪🤪🤪
# 44  gibran bukan kakeng kaleng rh anak joko w th c...
# 45                                                 th
# 46  soleh emil dardak kader demokrat wakil khofifa...
# 47                                  terimakasih paman
# 48                            all in prabowo gibran ❤
# 49            bali menang telak pragib indonesia emas
# 50  ir soekarno pdip bos 😎 liat berita ganjar pran...
# 51           menangis bro ada kartunya prabowo menang
# 52                             gibran sang penghianat
#
#                                           token_texts  \
# 0   [mas, gibran, pria, mudah, bradalah, generasi,...
# 1   [prediksi, prabowo, gibran, menang, diatas, pe...
# 2          [gibran, kucluk, gayane, koyo, baim, wong]
# 3   [semenjak, kalah, terus, jadi, menhan, jadi, k...
# 4     [mantap, kali, pak, prabowo, mas, gibran, 🎉❤🇮🇩]
# 5   [pada, protes, yabila, perlu, syaratnya, usia,...
# 6   [katanya, negara, demokrasisiapa, aja, masuk, ...
# 7                        [demokrasi, indonesia, mati]
# 8                                  [ganjar, aja, deh]
# 9            [katanya, ngk, batas, usia, mana, benar]
# 10                                         [emng, jd]
# 11  [tetep, yakin, prabowo, gibran, menang, putara...
# 12                                  [prabowo, gibran]
# 13                  [usianya, paling, sepuh, pilihan]
# 14      [ganjarmahfud, bos, ora, sudi, pilih, gibran]
# 15  [rakyat, benerquot, jijik, dg, caranya, jadi, ...
# 16           [makanya, mending, coblos, prabowo, aja]
# 17      [prabowo, gibran, gugur, udah, ingkar, janji]
# 18                               [gk, jadi, slamanya]
# 19              [prabowogibran, tetap, jadi, r, 🎉🎉🎉🎉]
# 20  [harusnya, prabowo, aniestapi, kalau, begini, ...
# 21                                      [gak, ngurus]
# 22                   [lihat, mukanya, aja, dah, muak]
# 23  [semoga, gagal, selalu, mendukung, pak, prabow...
# 24                                       [iya, bener]
# 25                     [emang, klw, wakilnya, gibran]
# 26  [mau, tanya, min, gibran, udah, keluar, blm, p...
# 29  [cawapres, aja, bangga, pilih, dunk, prabowo, ...
# 30  [lanjutkan, kedunguan, kalian, komentar, gibah...
# 31  [blm, jadi, pemilu, jamin, sdh, kalahamin, gan...
# 32  [kasian, ganjar, kalo, gak, pdip🤣, kasian, ani...
# 33  [ogah, bngt, pilih, cawapres, karbitan, paksa, 😊]
# 34  [pilih, kelompok, durhaka, amin, rais, cak, im...
# 35                                         [ampassss]
# 36  [semangat, nyoblos, prabowo, gibran, indonesia...
# 37  [tim, pemenangan, prabowobraldi, taher, kiki, ...
# 38  [roki, gerunk, amin, rais, dukung, aniesmuhaim...
# 39                        [moal, milih, tetep, anies]
# 40                                             [rais]
# 41                          [tim, pembela, nepotisme]
# 42                             [santai, casual, jos❤]
# 43            [tenang, tenang, pak, mk, mk, wakkk🤪🤪🤪]
# 44  [gibran, bukan, kakeng, kaleng, rh, anak, joko...
# 45                                               [th]
# 46  [soleh, emil, dardak, kader, demokrat, wakil, ...
# 47                               [terimakasih, paman]
# 48                      [all, in, prabowo, gibran, ❤]
# 49     [bali, menang, telak, pragib, indonesia, emas]
# 50  [ir, soekarno, pdip, bos, 😎, liat, berita, gan...
# 51    [menangis, bro, ada, kartunya, prabowo, menang]
# 52                         [gibran, sang, penghianat]
#
#                                            freq_words  \
# 0   {'mas': 1, 'gibran': 2, 'pria': 1, 'mudah': 1,...
# 1   {'prediksi': 1, 'prabowo': 1, 'gibran': 2, 'me...
# 2   {'gibran': 1, 'kucluk': 1, 'gayane': 1, 'koyo'...
# 3   {'semenjak': 1, 'kalah': 1, 'terus': 1, 'jadi'...
# 4   {'mantap': 1, 'kali': 1, 'pak': 1, 'prabowo': ...
# 5   {'pada': 1, 'protes': 1, 'yabila': 1, 'perlu':...
# 6   {'katanya': 1, 'negara': 1, 'demokrasisiapa': ...
# 7         {'demokrasi': 1, 'indonesia': 1, 'mati': 1}
# 8                   {'ganjar': 1, 'aja': 1, 'deh': 1}
# 9   {'katanya': 1, 'ngk': 1, 'batas': 1, 'usia': 1...
# 10                               {'emng': 1, 'jd': 1}
# 11  {'tetep': 1, 'yakin': 1, 'prabowo': 1, 'gibran...
# 12                        {'prabowo': 1, 'gibran': 1}
# 13  {'usianya': 1, 'paling': 1, 'sepuh': 1, 'pilih...
# 14  {'ganjarmahfud': 1, 'bos': 1, 'ora': 1, 'sudi'...
# 15  {'rakyat': 1, 'benerquot': 1, 'jijik': 1, 'dg'...
# 16  {'makanya': 1, 'mending': 1, 'coblos': 1, 'pra...
# 17  {'prabowo': 1, 'gibran': 1, 'gugur': 1, 'udah'...
# 18                {'gk': 1, 'jadi': 1, 'slamanya': 1}
# 19  {'prabowogibran': 1, 'tetap': 1, 'jadi': 1, 'r...
# 20  {'harusnya': 1, 'prabowo': 1, 'aniestapi': 1, ...
# 21                            {'gak': 1, 'ngurus': 1}
# 22  {'lihat': 1, 'mukanya': 1, 'aja': 1, 'dah': 1,...
# 23  {'semoga': 1, 'gagal': 1, 'selalu': 1, 'menduk...
# 24                             {'iya': 1, 'bener': 1}
# 25  {'emang': 1, 'klw': 1, 'wakilnya': 1, 'gibran'...
# 26  {'mau': 1, 'tanya': 1, 'min': 1, 'gibran': 1, ...
# 29  {'cawapres': 1, 'aja': 1, 'bangga': 1, 'pilih'...
# 30  {'lanjutkan': 1, 'kedunguan': 1, 'kalian': 2, ...
# 31  {'blm': 1, 'jadi': 1, 'pemilu': 1, 'jamin': 1,...
# 32  {'kasian': 2, 'ganjar': 1, 'kalo': 2, 'gak': 3...
# 33  {'ogah': 1, 'bngt': 1, 'pilih': 1, 'cawapres':...
# 34  {'pilih': 1, 'kelompok': 1, 'durhaka': 1, 'ami...
# 35                                    {'ampassss': 1}
# 36  {'semangat': 1, 'nyoblos': 1, 'prabowo': 1, 'g...
# 37  {'tim': 1, 'pemenangan': 1, 'prabowobraldi': 1...
# 38  {'roki': 1, 'gerunk': 1, 'amin': 1, 'rais': 1,...
# 39    {'moal': 1, 'milih': 1, 'tetep': 1, 'anies': 1}
# 40                                        {'rais': 1}
# 41           {'tim': 1, 'pembela': 1, 'nepotisme': 1}
# 42              {'santai': 1, 'casual': 1, 'jos❤': 1}
# 43    {'tenang': 2, 'pak': 1, 'mk': 2, 'wakkk🤪🤪🤪': 1}
# 44  {'gibran': 1, 'bukan': 1, 'kakeng': 1, 'kaleng...
# 45                                          {'th': 1}
# 46  {'soleh': 1, 'emil': 1, 'dardak': 1, 'kader': ...
# 47                     {'terimakasih': 1, 'paman': 1}
# 48  {'all': 1, 'in': 1, 'prabowo': 1, 'gibran': 1,...
# 49  {'bali': 1, 'menang': 1, 'telak': 1, 'pragib':...
# 50  {'ir': 1, 'soekarno': 1, 'pdip': 1, 'bos': 1, ...
# 51  {'menangis': 1, 'bro': 1, 'ada': 1, 'kartunya'...
# 52          {'gibran': 1, 'sang': 1, 'penghianat': 1}
#
#                                         stemmed_texts    label  score  \
# 0   [mas, gibran, pria, mudah, bradalah, generasi,...  Positif      1
# 1   [prediksi, prabowo, gibran, menang, atas, pers...  Positif      1
# 2          [gibran, kucluk, gayane, koyo, baim, wong]   Netral      0
# 3   [semenjak, kalah, terus, jadi, menhan, jadi, k...   Netral      0
# 4         [mantap, kali, pak, prabowo, mas, gibran, ]  Positif      1
# 5   [pada, protes, yabila, perlu, syarat, usia, ta...  Positif      1
# 6   [kata, negara, demokrasisiapa, aja, masuk, jad...   Netral      0
# 7                        [demokrasi, indonesia, mati]  Negatif     -1
# 8                                  [ganjar, aja, deh]   Netral      0
# 9               [kata, ngk, batas, usia, mana, benar]  Positif      1
# 10                                         [emng, jd]  Positif      1
# 11  [tetep, yakin, prabowo, gibran, menang, putar,...  Positif      1
# 12                                  [prabowo, gibran]   Netral      0
# 13                       [usia, paling, sepuh, pilih]   Netral      0
# 14      [ganjarmahfud, bos, ora, sudi, pilih, gibran]   Netral      0
# 15  [rakyat, benerquot, jijik, dg, cara, jadi, caw...  Negatif     -1
# 16           [makanya, mending, coblos, prabowo, aja]  Positif      1
# 17      [prabowo, gibran, gugur, udah, ingkar, janji]   Netral      0
# 18                               [gk, jadi, slamanya]   Netral      0
# 19                  [prabowogibran, tetap, jadi, r, ]   Netral      0
# 20  [harus, prabowo, aniestapi, kalau, begini, men...  Positif      1
# 21                                      [gak, ngurus]   Netral      0
# 22                      [lihat, muka, aja, dah, muak]   Netral      0
# 23  [moga, gagal, selalu, dukung, pak, prabowo, te...  Negatif     -1
# 24                                       [iya, bener]  Positif      1
# 25                        [emang, klw, wakil, gibran]  Positif      1
# 26  [mau, tanya, min, gibran, udah, keluar, blm, p...   Netral      0
# 29  [cawapres, aja, bangga, pilih, dunk, prabowo, ...  Positif      1
# 30  [lanjut, dungu, kalian, komentar, gibahnyinyir...  Positif      1
# 31  [blm, jadi, milu, jamin, sdh, kalahamin, ganja...   Netral      0
# 32  [kasi, ganjar, kalo, gak, pdip, kasi, anies, k...  Negatif     -1
# 33   [ogah, bngt, pilih, cawapres, karbitan, paksa, ]  Negatif     -1
# 34  [pilih, kelompok, durhaka, amin, rais, cak, im...  Negatif     -1
# 35                                         [ampassss]   Netral      0
# 36  [semangat, nyoblos, prabowo, gibran, indonesia...   Netral      0
# 37  [tim, menang, prabowobraldi, taher, kiki, kaes...  Positif      1
# 38  [roki, gerunk, amin, rais, dukung, aniesmuhaim...   Netral      0
# 39                        [moal, milih, tetep, anies]   Netral      0
# 40                                             [rais]   Netral      0
# 41                             [tim, bela, nepotisme]   Netral      0
# 42                              [santai, casual, jos]  Negatif     -1
# 43               [tenang, tenang, pak, mk, mk, wakkk]  Positif      1
# 44  [gibran, bukan, kakeng, kaleng, rh, anak, joko...  Positif      1
# 45                                               [th]   Netral      0
# 46  [soleh, emil, dardak, kader, demokrat, wakil, ...  Positif      1
# 47                               [terimakasih, paman]   Netral      0
# 48                       [all, in, prabowo, gibran, ]   Netral      0
# 49      [bal, menang, telak, pragib, indonesia, emas]  Positif      1
# 50  [ir, soekarno, pdip, bos, , liat, berita, ganj...   Netral      0
# 51         [menang, bro, ada, kartu, prabowo, menang]  Positif      1
# 52                         [gibran, sang, penghianat]   Netral      0
#
#                                             translate  polarity  subjectivity
# 0   Mas Gibran is an easy man who is the next gene...  0.144444      0.377778
# 1   Prabowo Gibran's prediction of winning above p...  0.133333      0.316667
# 2                    gibran kucluk is like a baim man  0.000000      0.000000
# 3   Since losing, he continues to be defense minis...  0.000000      0.000000
# 4                  Great sir Prabowo, Mas Gibran 🎉❤🇮🇩  0.800000      0.750000
# 5   at the protest, if necessary, the requirement ...  0.162500      0.566667
# 6   He said that in a democratic country, whoever ...  0.000000      0.000000
# 7                        Indonesian democracy is dead -0.200000      0.400000
# 8                                      just reward me  0.000000      0.000000
# 9        he said there is no age limit, which is true  0.350000      0.650000
# 10                                       It really is  0.200000      0.200000
# 11  Still confident that Prabowo Gibran will win t...  0.275000      0.408333
# 12                                     Prabowo Gibran  0.000000      0.000000
# 13                       the oldest age is the choice  0.000000      0.000000
# 14    Gangarmahfud boss doesn't want to choose Gibran  0.000000      0.000000
# 15  The people are really disgusted with the way h... -1.000000      1.000000
# 16            So it's better to just vote for Prabowo  0.500000      0.500000
# 17          Prabowo Gibran fell and broke his promise  0.000000      0.000000
# 18                              it won't last forever  0.000000      0.066667
# 19                       prabowogibran remains r 🎉🎉🎉🎉  0.000000      0.000000
# 20  Prabowo should be Anies, but if it's like this...  0.500000      0.500000
# 21                              don't take care of it  0.000000      0.000000
# 22                      look at his face, he's fed up  0.000000      0.000000
# 23  I hope you fail to always support Pak Prabowo ... -0.500000      0.300000
# 24                                         Yes, right  0.285714      0.535714
# 25                     It's true that Gibran's deputy  0.350000      0.650000
# 26  I want to ask Min, is Gibran out yet without PDP?  0.000000      0.000000
# 29  Even the vice presidential candidate is proud ...  0.800000      1.000000
# 30  continue your stupid comments, gibah, blasphem...  0.490000      0.750000
# 31  It's not yet an election, I guarantee you'll b...  0.000000      1.000000
# 32  poor punishment if you don't pdip🤣 poor anies ... -0.400000      0.600000
# 33  I really don't want to choose a forced preside... -0.050000      0.200000
# 34  vote for the disobedient group amen rais cak i... -0.400000      0.522222
# 35                                           ampassss  0.000000      0.000000
# 36       Prabowo Gibran's spirit to vote for progress  0.000000      0.000000
# 37  prabowobraldi winning team taher kiki kaesang ...  0.500000      0.750000
# 38      roki gerunk amen rais support aniesmuhaimin 🤣  0.000000      0.000000
# 39                      will not choose to stay anies  0.000000      0.000000
# 40                                      the president  0.000000      0.000000
# 41                              nepotism defense team  0.000000      0.000000
# 42                                  relax casual jos❤ -0.500000      0.866667
# 43                       calm down sir mk mk wakkk🤪🤪🤪  0.072222      0.519444
# 44  Gibran is not the old man, Joko's son, the gra...  0.100000      0.200000
# 45                                                 th  0.000000      0.000000
# 46  Soleh Emil Dardak Democratic cadre Deputy Khof...  0.100000      0.200000
# 47                                    thank you Uncle  0.000000      0.000000
# 48                            all in prabowo gibran ❤  0.000000      0.000000
# 49         Bali wins hands down Pragib Indonesia Gold  0.072222      0.244444
# 50  ir soekarno pdip boss 😎 see the news of Ganjar...  0.000000      0.000000
# 51      crying bro, there is a card that Prabowo wins  0.050000      0.400000
# 52                                 Gibran the traitor  0.000000      0.000000

# %%
# fisualisasi

fig, ax = plt.subplots(figsize = (6, 6))
sizes = [count for count in df_final['label'].value_counts()]
labels = list(df_final['label'].value_counts().index)
explode = (0.1, 0, 0)
ax.pie(x = sizes, labels = labels, autopct = '%1.1f%%', explode = explode, textprops={'fontsize': 14})
ax.set_title('Sentiment Polarity on Tweets Data', fontsize = 16, pad = 20)
plt.show()

# %%
pd.set_option('display.max_colwidth', 3000)
positive_comments = df_final[df_final['label'] == 'Positif']
positive_comments = positive_comments[['clear', 'polarity', 'label','translate']].sort_values(by = 'polarity', ascending=False).reset_index(drop = True)
positive_comments.index += 1
positive_comments[0:10]
# Out:
#                                                                                                                                               clear  \
# 1                                                                                                           mantap kali pak prabowo mas gibran 🎉❤🇮🇩
# 2                                                                                                     cawapres aja bangga pilih dunk prabowo capres
# 3                                                                                                                makanya mending coblos prabowo aja
# 4                                                                                    harusnya prabowo aniestapi kalau begini mending anies cak imin
# 5                                           tim pemenangan prabowobraldi taher kiki kaesang cakil fadli zonk fahri hamzah roki gerung rizal ramli 😂
# 6   lanjutkan kedunguan kalian komentar gibahnyinyir hujatbohong amp fitnah mmg kalian paling hebat paling baik paling suksestapi boong🤣tapi dungu🤣
# 7                                                                                                                 katanya ngk batas usia mana benar
# 8                                                                                                                         emang klw wakilnya gibran
# 9                                                                                                                                         iya bener
# 10                                                                                                  tetep yakin prabowo gibran menang putaran kedua
#
#     polarity    label  \
# 1   0.800000  Positif
# 2   0.800000  Positif
# 3   0.500000  Positif
# 4   0.500000  Positif
# 5   0.500000  Positif
# 6   0.490000  Positif
# 7   0.350000  Positif
# 8   0.350000  Positif
# 9   0.285714  Positif
# 10  0.275000  Positif
#
#                                                                                                                                                   translate
# 1                                                                                                                        Great sir Prabowo, Mas Gibran 🎉❤🇮🇩
# 2                                                            Even the vice presidential candidate is proud to choose Dunk Prabowo as presidential candidate
# 3                                                                                                                   So it's better to just vote for Prabowo
# 4                                                                             Prabowo should be Anies, but if it's like this, it's better if Anies Cak Imin
# 5                                                     prabowobraldi winning team taher kiki kaesang cakil fadli zonk fahri hamzah roki gerung rizal ramli 😂
# 6   continue your stupid comments, gibah, blasphemy and slander, you are the greatest, the best, the most successful, but you are lying🤣but you are stupid🤣
# 7                                                                                                              he said there is no age limit, which is true
# 8                                                                                                                            It's true that Gibran's deputy
# 9                                                                                                                                                Yes, right
# 10                                                                                            Still confident that Prabowo Gibran will win the second round

# %%
pd.set_option('display.max_colwidth', 3000)
positive_comments = df_final[df_final['label'] == 'Negatif']
positive_comments = positive_comments[['clear', 'polarity', 'label','translate']].sort_values(by = 'polarity', ascending=False).reset_index(drop = True)
positive_comments.index += 1
positive_comments[0:10]
# Out:
#                                                                                                                                                                   clear  \
# 1                                                                                                                             ogah bngt pilih cawapres karbitan paksa 😊
# 2                                                                                                                                              demokrasi indonesia mati
# 3                                       pilih kelompok durhaka amin rais cak imin roki gerung tu semua orang pembawa kesialan capres didukungnya selalu keok nyungsep 🤣
# 4  kasian ganjar kalo gak pdip🤣 kasian anies kalo gak nasdem🤣 petugas partai🤣jadi siapa ngatur negara rakyatnya ketua partailah prabowo ketua partai gak yg bs mendikte
# 5                                                          semoga gagal selalu mendukung pak prabowo setelah tau gibran huh ogah pak pak nya jangan gibran lah wakilnya
# 6                                                                                                                                                    santai casual jos❤
# 7                                                                                                                       rakyat benerquot jijik dg caranya jadi cawapres
#
#    polarity    label  \
# 1     -0.05  Negatif
# 2     -0.20  Negatif
# 3     -0.40  Negatif
# 4     -0.40  Negatif
# 5     -0.50  Negatif
# 6     -0.50  Negatif
# 7     -1.00  Negatif
#
#                                                                                                                                                                                                   translate
# 1                                                                                                                                           I really don't want to choose a forced presidential candidate 😊
# 2                                                                                                                                                                              Indonesian democracy is dead
# 3                                     vote for the disobedient group amen rais cak imin roki gerung that's all the people who bring bad luck the presidential candidate he supports always loses his shit 🤣
# 4  poor punishment if you don't pdip🤣 poor anies if you don't nasdem🤣 party officials🤣so who rules the country the people are the party chairman, prabowo, isn't the party chairman the one who can dictate
# 5                                                           I hope you fail to always support Pak Prabowo after finding out about Gibran, huh, don't give up, sir, don't give up on Gibran, be your deputy.
# 6                                                                                                                                                                                         relax casual jos❤
# 7                                                                                                                        The people are really disgusted with the way he became vice presidential candidate

# %%
# Visualize word cloud

list_words=''
for tweet in df_final['token_texts']:
    for word in tweet:
        list_words += ' '+(word)

wordcloud = WordCloud(width = 600, height = 400, background_color = 'black', min_font_size = 10).generate(list_words)
fig, ax = plt.subplots(figsize = (8, 6))
ax.set_title('Word Cloud of Tweets Data', fontsize = 18)
ax.grid(False)
ax.imshow((wordcloud))
fig.tight_layout(pad=0)
ax.axis('off')
plt.show()

# %%
tokens = nltk.tokenize.word_tokenize(list_words)
fdist=nltk.FreqDist(tokens)
fdist
# Out:
# FreqDist({'gibran': 18, 'prabowo': 13, 'jadi': 7, 'menang': 5, 'pak': 5, 'aja': 5, 'gak': 5, 'anies': 4, 'ganjar': 4, 'paling': 4, ...})
